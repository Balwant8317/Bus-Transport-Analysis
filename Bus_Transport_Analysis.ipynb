# %%
import pandas as pd
import numpy as np
import datetime
from datetime import datetime

# %%
df=pd.read_csv("Weekly_Boarding.csv")
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9864\3588914749.py:1: DtypeWarning: Columns (1,9,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("Weekly_Boarding.csv")

# %%
df.shape
# Out:
# (10857234, 14)

# %%
df.columns
# Out:
# Index(['TripID', 'RouteID', 'StopID', 'StopName', 'WeekBeginning',
#        'NumberOfBoardings', 'formatted_address', 'latitude', 'longitude',
#        'postcode', 'type', 'route_desc', 'dist_from_centre', 'holiday_label'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10857234 entries, 0 to 10857233
# Data columns (total 14 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   TripID             int64
#  1   RouteID            object
#  2   StopID             int64
#  3   StopName           object
#  4   WeekBeginning      object
#  5   NumberOfBoardings  int64
#  6   formatted_address  object
#  7   latitude           float64
#  8   longitude          float64
#  9   postcode           object
#  10  type               object
#  11  route_desc         object
#  12  dist_from_centre   float64
#  13  holiday_label      int64
# dtypes: float64(3), int64(4), object(7)
# memory usage: 1.1+ GB

# %%
df.isnull().sum()*100/len(df)
# Out:
# TripID                0.000000
# RouteID               0.000000
# StopID                0.000000
# StopName              0.000000
# WeekBeginning         0.000000
# NumberOfBoardings     0.000000
# formatted_address     0.032292
# latitude              0.000000
# longitude             0.000000
# postcode              3.915187
# type                  0.000000
# route_desc           19.402898
# dist_from_centre      0.000000
# holiday_label         0.000000
# dtype: float64

# %%
df['route_desc'].value_counts()
# Out:
# via Flinders University, Goodwood Road, City & Prospect Road. Service operates 7 days.                                                                                                                                              358005
# via City & O-bahn. Service operates 7 days.                                                                                                                                                                                         331442
# via Military Road, Henley Beach Road, City, Coorara Avenue & Stradbroke Road. Service operates 7 days.                                                                                                                              326004
# via Main North Road. Service operates 7 days.                                                                                                                                                                                       230667
# via Regency Road, Burnside Village, Cross Road, Flinders University, Flinders Medical Centre, Marion Centre Interchange, Glenelg Interchange, Harbour Town, Henley Beach, Queen Elizabeth Hospital & Arndale Centre Interchange.    228373
#                                                                                                                                                                                                                                      ...
# School Service. Via Grange, Tennyson, West Lakes & Semaphore.                                                                                                                                                                           24
# School Service. Via Marryatville, Norwood, Kensington, Glynde, Paradise, Athelstone & Newton.                                                                                                                                           23
# School Service. Via Bartles Rd, East Tce & North Tce.                                                                                                                                                                                   23
# School Service. Via Largs Bay, Taperoo, North Haven, Outer Harbor, Osborne & Largs North.                                                                                                                                               22
# School Service. Blackwood High School to stop 30 Flagstaff Hill Road, Darlington.                                                                                                                                                       21
# Name: route_desc, Length: 440, dtype: int64

# %%
df.head()
# Out:
#    TripID RouteID  StopID                    StopName WeekBeginning  \
# 0   23631     100   14156                181 Cross Rd    2013-06-30
# 1   23631     100   14144                177 Cross Rd    2013-06-30
# 2   23632     100   14132                175 Cross Rd    2013-06-30
# 3   23633     100   12266  Zone A Arndale Interchange    2013-06-30
# 4   23633     100   14147                178 Cross Rd    2013-06-30
#
#    NumberOfBoardings                                  formatted_address  \
# 0                  1   181 Cross Rd, Westbourne Park SA 5041, Australia
# 1                  1   177 Cross Rd, Westbourne Park SA 5041, Australia
# 2                  1   175 Cross Rd, Westbourne Park SA 5041, Australia
# 3                  2  Zone A Arndale Interchange - South side, Kilke...
# 4                  1           178 Cross Rd, Malvern SA 5061, Australia
#
#     latitude   longitude postcode             type  \
# 0 -34.966656  138.592148     5041   street_address
# 1 -34.966607  138.592301     5041   street_address
# 2 -34.966758  138.592715     5041   street_address
# 3 -34.875160  138.551628     5009  transit_station
# 4 -34.964960  138.611477     5061   street_address
#
#                                           route_desc  dist_from_centre  \
# 0  via Woodville Road, Holbrooks Road, Marion Roa...          5.180961
# 1  via Woodville Road, Holbrooks Road, Marion Roa...          5.172525
# 2  via Woodville Road, Holbrooks Road, Marion Roa...          5.180709
# 3  via Woodville Road, Holbrooks Road, Marion Roa...          7.057549
# 4  via Woodville Road, Holbrooks Road, Marion Roa...          4.900099
#
#    holiday_label
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0

# %%
df.shape
# Out:
# (10857234, 14)

# %%
grouped = df.groupby(['StopName','WeekBeginning','type'])
grouped.head()
# Out:
#           TripID RouteID  StopID                    StopName WeekBeginning  \
# 0          23631     100   14156                181 Cross Rd    2013-06-30
# 1          23631     100   14144                177 Cross Rd    2013-06-30
# 2          23632     100   14132                175 Cross Rd    2013-06-30
# 3          23633     100   12266  Zone A Arndale Interchange    2013-06-30
# 4          23633     100   14147                178 Cross Rd    2013-06-30
# ...          ...     ...     ...                         ...           ...
# 10838923   12956     W91   14666               21A Cashel St    2014-07-06
# 10847721   51757    W91C   14754               22A Cashel St    2013-12-29
# 10847746   51758    W91C   14754               22A Cashel St    2013-12-29
# 10847793   51761    W91C   14754               22A Cashel St    2013-12-29
# 10847813   51762    W91C   14754               22A Cashel St    2013-12-29
#
#           NumberOfBoardings  \
# 0                         1
# 1                         1
# 2                         1
# 3                         2
# 4                         1
# ...                     ...
# 10838923                  1
# 10847721                  1
# 10847746                  4
# 10847793                  3
# 10847813                  1
#
#                                           formatted_address   latitude  \
# 0          181 Cross Rd, Westbourne Park SA 5041, Australia -34.966656
# 1          177 Cross Rd, Westbourne Park SA 5041, Australia -34.966607
# 2          175 Cross Rd, Westbourne Park SA 5041, Australia -34.966758
# 3         Zone A Arndale Interchange - South side, Kilke... -34.875160
# 4                  178 Cross Rd, Malvern SA 5061, Australia -34.964960
# ...                                                     ...        ...
# 10838923         21A Cashel St, Pasadena SA 5042, Australia -34.996703
# 10847721          22 Cashel St, St Marys SA 5042, Australia -34.995282
# 10847746          22 Cashel St, St Marys SA 5042, Australia -34.995282
# 10847793          22 Cashel St, St Marys SA 5042, Australia -34.995282
# 10847813          22 Cashel St, St Marys SA 5042, Australia -34.995282
#
#            longitude postcode             type  \
# 0         138.592148     5041   street_address
# 1         138.592301     5041   street_address
# 2         138.592715     5041   street_address
# 3         138.551628     5009  transit_station
# 4         138.611477     5061   street_address
# ...              ...      ...              ...
# 10838923  138.582702   5042.0   street_address
# 10847721  138.582069   5042.0   street_address
# 10847746  138.582069   5042.0   street_address
# 10847793  138.582069   5042.0   street_address
# 10847813  138.582069   5042.0   street_address
#
#                                                  route_desc  dist_from_centre  \
# 0         via Woodville Road, Holbrooks Road, Marion Roa...          5.180961
# 1         via Woodville Road, Holbrooks Road, Marion Roa...          5.172525
# 2         via Woodville Road, Holbrooks Road, Marion Roa...          5.180709
# 3         via Woodville Road, Holbrooks Road, Marion Roa...          7.057549
# 4         via Woodville Road, Holbrooks Road, Marion Roa...          4.900099
# ...                                                     ...               ...
# 10838923  via Cashel Street, Winston Avenue, City and Si...          8.631341
# 10847721                                Terminates in city.          8.491593
# 10847746                                Terminates in city.          8.491593
# 10847793                                Terminates in city.          8.491593
# 10847813                                Terminates in city.          8.491593
#
#           holiday_label
# 0                     0
# 1                     0
# 2                     0
# 3                     0
# 4                     0
# ...                 ...
# 10838923              0
# 10847721              1
# 10847746              1
# 10847793              1
# 10847813              1
#
# [958683 rows x 14 columns]

# %%
df['type'].value_counts()
# Out:
# street_address        6653561
# transit_station       1604089
# premise               1307928
# route                 1127183
# political               71201
# point_of_interest       46607
# intersection            34142
# subpremise               5892
# school                   5248
# real_estate_agency        525
# university                470
# restaurant                303
# supermarket                57
# travel_agency              21
# store                       4
# post_office                 3
# Name: type, dtype: int64

# %%
# st_week_grp1 = pd.DataFrame(data.groupby(['StopName','WeekBeginning','type']).agg({'NumberOfBoardings': ['sum', 'count']})).reset_index()
grouped = df.groupby(['StopName','WeekBeginning','type']).agg({'NumberOfBoardings': ['sum', 'count','max','min']})
grouped.columns = ["_".join(x) for x in grouped.columns.ravel()]
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9864\875431818.py:3: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   grouped.columns = ["_".join(x) for x in grouped.columns.ravel()]

# %% [markdown]
# ##### grouped.head(10)

# %%
grouped.columns
# Out:
# Index(['NumberOfBoardings_sum', 'NumberOfBoardings_count',
#        'NumberOfBoardings_max', 'NumberOfBoardings_min'],
#       dtype='object')

# %%
grouped.shape
# Out:
# (207864, 4)

# %%
st_week_grp = pd.DataFrame(grouped).reset_index()
st_week_grp.shape
# Out:
# (207864, 7)

# %%
st_week_grp.head()
# Out:
#       StopName WeekBeginning            type  NumberOfBoardings_sum  \
# 0  1 Anzac Hwy    2013-06-30  street_address                   1003
# 1  1 Anzac Hwy    2013-07-07  street_address                    783
# 2  1 Anzac Hwy    2013-07-14  street_address                    843
# 3  1 Anzac Hwy    2013-07-21  street_address                    710
# 4  1 Anzac Hwy    2013-07-28  street_address                    898
#
#    NumberOfBoardings_count  NumberOfBoardings_max  NumberOfBoardings_min
# 0                      378                     51                      1
# 1                      360                     28                      1
# 2                      343                     45                      1
# 3                      356                     28                      1
# 4                      379                     41                      1

# %%
st_week_grp1 = pd.DataFrame(st_week_grp.groupby('StopName')["WeekBeginning"].count()).reset_index()
st_week_grp1.head()
# Out:
#          StopName  WeekBeginning
# 0     1 Anzac Hwy             54
# 1    1 Bartels Rd             54
# 2    1 Botanic Rd             54
# 3      1 Frome Rd             54
# 4  1 Fullarton Rd             54

# %%
#Gathering only the Stop Name which having all 54 weeks of Dat
aa = list(st_week_grp1[st_week_grp1['WeekBeginning'] == 54]['StopName'])
aa[1:20]
# Out:
# ['1 Bartels Rd',
#  '1 Botanic Rd',
#  '1 Frome Rd',
#  '1 Fullarton Rd',
#  '1 George St',
#  '1 Glen Osmond Rd',
#  '1 Goodwood Rd',
#  '1 Henley Beach Rd',
#  '1 Kensington Rd',
#  '1 King William Rd',
#  '1 Port Rd',
#  '1 Sir Donald Bradman Dr',
#  '1 Sir Edwin Smith Av',
#  '1 Unley Rd',
#  '10  Holbrooks Rd',
#  '10  Marion Rd',
#  '10  Portrush Rd',
#  '10 Airport Rd',
#  '10 Anzac Hwy']

# %%
len(aa)
# Out:
# 3249

# %%
len(aa)
# Out:
# 3249

# %%
st_week_grp1['WeekBeginning'].value_counts()
# Out:
# 54    3249
# 53     113
# 52      76
# 51      44
# 41      37
# 50      33
# 40      31
# 48      31
# 47      26
# 2       24
# 45      23
# 49      21
# 46      20
# 1       19
# 34      18
# 20      18
# 27      17
# 35      17
# 9       15
# 42      15
# 37      14
# 44      13
# 17      13
# 24      13
# 39      12
# 32      12
# 38      12
# 12      11
# 8       11
# 43      11
# 26      11
# 30      11
# 15      11
# 16      10
# 11      10
# 23      10
# 6       10
# 31      10
# 21      10
# 29       9
# 4        9
# 22       9
# 3        9
# 7        8
# 5        8
# 33       8
# 36       7
# 28       7
# 18       6
# 10       6
# 13       5
# 19       5
# 14       4
# 25       3
# Name: WeekBeginning, dtype: int64

# %%
bb = st_week_grp[st_week_grp['StopName'].isin(aa)]
bb.head()
# Out:
#       StopName WeekBeginning            type  NumberOfBoardings_sum  \
# 0  1 Anzac Hwy    2013-06-30  street_address                   1003
# 1  1 Anzac Hwy    2013-07-07  street_address                    783
# 2  1 Anzac Hwy    2013-07-14  street_address                    843
# 3  1 Anzac Hwy    2013-07-21  street_address                    710
# 4  1 Anzac Hwy    2013-07-28  street_address                    898
#
#    NumberOfBoardings_count  NumberOfBoardings_max  NumberOfBoardings_min
# 0                      378                     51                      1
# 1                      360                     28                      1
# 2                      343                     45                      1
# 3                      356                     28                      1
# 4                      379                     41                      1

# %%
bb.shape
# Out:
# (175446, 7)

# %%
type(bb)
# Out:
# pandas.core.frame.DataFrame

# %%
#removing the stoppage which are not having the data of whole 54 weeks
new_data = df[df['StopName'].isin(aa)]
new_data.shape
print("data without stopage removing: ", df.shape)
print("data, after removing stoppage not having the data of whole 54 weeks: ", new_data.shape)
# Out:
# data without stopage removing:  (10857234, 14)
# data, after removing stoppage not having the data of whole 54 weeks:  (10567931, 14)

# %%
10857234-10567931
# Out:
# 289303

# %%
new_data.head()
# Out:
#    TripID RouteID  StopID                    StopName WeekBeginning  \
# 0   23631     100   14156                181 Cross Rd    2013-06-30
# 1   23631     100   14144                177 Cross Rd    2013-06-30
# 2   23632     100   14132                175 Cross Rd    2013-06-30
# 3   23633     100   12266  Zone A Arndale Interchange    2013-06-30
# 4   23633     100   14147                178 Cross Rd    2013-06-30
#
#    NumberOfBoardings                                  formatted_address  \
# 0                  1   181 Cross Rd, Westbourne Park SA 5041, Australia
# 1                  1   177 Cross Rd, Westbourne Park SA 5041, Australia
# 2                  1   175 Cross Rd, Westbourne Park SA 5041, Australia
# 3                  2  Zone A Arndale Interchange - South side, Kilke...
# 4                  1           178 Cross Rd, Malvern SA 5061, Australia
#
#     latitude   longitude postcode             type  \
# 0 -34.966656  138.592148     5041   street_address
# 1 -34.966607  138.592301     5041   street_address
# 2 -34.966758  138.592715     5041   street_address
# 3 -34.875160  138.551628     5009  transit_station
# 4 -34.964960  138.611477     5061   street_address
#
#                                           route_desc  dist_from_centre  \
# 0  via Woodville Road, Holbrooks Road, Marion Roa...          5.180961
# 1  via Woodville Road, Holbrooks Road, Marion Roa...          5.172525
# 2  via Woodville Road, Holbrooks Road, Marion Roa...          5.180709
# 3  via Woodville Road, Holbrooks Road, Marion Roa...          7.057549
# 4  via Woodville Road, Holbrooks Road, Marion Roa...          4.900099
#
#    holiday_label
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0

# %%
filtered_data = new_data[new_data['dist_from_centre'] <= 100]
filtered_data.shape
# Out:
# (10341468, 14)

# %%
10567931-10341468
# Out:
# 226463

# %%
#No of boarding for each stopage in all weeks
#bb["StopName"].groupby(NumberOfBoardings_sum)
stopageName_with_boarding = bb.groupby(['StopName']).agg({'NumberOfBoardings_sum': ['sum']})

#stopageName_with_boarding.columns = ["_".join(x) for x in stopageName_with_boarding.columns.ravel()]
#stopageName_with_boarding.head()
stopageName_with_boarding = pd.DataFrame(stopageName_with_boarding.reset_index())

# %%
stopageName_with_boarding.head()
# Out:
#          StopName NumberOfBoardings_sum
#                                     sum
# 0     1 Anzac Hwy                 39429
# 1    1 Bartels Rd                  8412
# 2    1 Botanic Rd                 14868
# 3      1 Frome Rd                 67458
# 4  1 Fullarton Rd                   585

# %%
#type(stopageName_with_boarding)
stopageName_with_boarding.columns = ["StopName","Total_boarding_on_the_stopage"]
#stopageName_with_boarding.shape
stopageName_with_boarding.head()
# Out:
#          StopName  Total_boarding_on_the_stopage
# 0     1 Anzac Hwy                          39429
# 1    1 Bartels Rd                           8412
# 2    1 Botanic Rd                          14868
# 3      1 Frome Rd                          67458
# 4  1 Fullarton Rd                            585

# %%
df.isnull().sum()*100/len(df)
# Out:
# TripID                0.000000
# RouteID               0.000000
# StopID                0.000000
# StopName              0.000000
# WeekBeginning         0.000000
# NumberOfBoardings     0.000000
# formatted_address     0.032292
# latitude              0.000000
# longitude             0.000000
# postcode              3.915187
# type                  0.000000
# route_desc           19.402898
# dist_from_centre      0.000000
# holiday_label         0.000000
# dtype: float64

# %%
df['route_desc'] = df['route_desc'].fillna('others')

# %%
df.isnull().sum()*100/len(df)
# Out:
# TripID               0.000000
# RouteID              0.000000
# StopID               0.000000
# StopName             0.000000
# WeekBeginning        0.000000
# NumberOfBoardings    0.000000
# formatted_address    0.032292
# latitude             0.000000
# longitude            0.000000
# postcode             3.915187
# type                 0.000000
# route_desc           0.000000
# dist_from_centre     0.000000
# holiday_label        0.000000
# dtype: float64

# %%
df['route_desc'].value_counts()
# Out:
# others                                                                                                    2106618
# via Flinders University, Goodwood Road, City & Prospect Road. Service operates 7 days.                     358005
# via City & O-bahn. Service operates 7 days.                                                                331442
# via Military Road, Henley Beach Road, City, Coorara Avenue & Stradbroke Road. Service operates 7 days.     326004
# via Main North Road. Service operates 7 days.                                                              230667
#                                                                                                            ...
# School Service. Via Grange, Tennyson, West Lakes & Semaphore.                                                  24
# School Service. Via Bartles Rd, East Tce & North Tce.                                                          23
# School Service. Via Marryatville, Norwood, Kensington, Glynde, Paradise, Athelstone & Newton.                  23
# School Service. Via Largs Bay, Taperoo, North Haven, Outer Harbor, Osborne & Largs North.                      22
# School Service. Blackwood High School to stop 30 Flagstaff Hill Road, Darlington.                              21
# Name: route_desc, Length: 441, dtype: int64

# %%
df.isna().sum()
# Out:
# TripID                    0
# RouteID                   0
# StopID                    0
# StopName                  0
# WeekBeginning             0
# NumberOfBoardings         0
# formatted_address      3506
# latitude                  0
# longitude                 0
# postcode             425081
# type                      0
# route_desc                0
# dist_from_centre          0
# holiday_label             0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10857234 entries, 0 to 10857233
# Data columns (total 14 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   TripID             int64
#  1   RouteID            object
#  2   StopID             int64
#  3   StopName           object
#  4   WeekBeginning      object
#  5   NumberOfBoardings  int64
#  6   formatted_address  object
#  7   latitude           float64
#  8   longitude          float64
#  9   postcode           object
#  10  type               object
#  11  route_desc         object
#  12  dist_from_centre   float64
#  13  holiday_label      int64
# dtypes: float64(3), int64(4), object(7)
# memory usage: 1.1+ GB

# %%
df['formatted_address'].value_counts()
# Out:
# Currie St, Adelaide SA 5000, Australia                                 228514
# North Terrace, Adelaide SA, Australia                                  212860
# King William Street, Adelaide SA 5000, Australia                       130862
# Pulteney St, Adelaide SA 5000, Australia                               103164
# Lower North East Rd, South Australia, Australia                         82044
#                                                                         ...
# 134 Justs Rd, Sellicks Beach SA 5174, Australia                             1
# Sir Ross Smith Ave & Lady Gowrie Dr, North Haven SA 5018, Australia         1
# 96 Alawoona Rd, Munno Para SA 5115, Australia                               1
# 51 Bains Rd, Morphett Vale SA 5162, Australia                               1
# 53 O'Sullivan Beach Rd, Lonsdale SA 5160, Australia                         1
# Name: formatted_address, Length: 3242, dtype: int64

# %%
df['formatted_address'].isna().sum()
# Out:
# 3506

# %%
df.head()
# Out:
#    TripID RouteID  StopID                    StopName WeekBeginning  \
# 0   23631     100   14156                181 Cross Rd    2013-06-30
# 1   23631     100   14144                177 Cross Rd    2013-06-30
# 2   23632     100   14132                175 Cross Rd    2013-06-30
# 3   23633     100   12266  Zone A Arndale Interchange    2013-06-30
# 4   23633     100   14147                178 Cross Rd    2013-06-30
#
#    NumberOfBoardings                                  formatted_address  \
# 0                  1   181 Cross Rd, Westbourne Park SA 5041, Australia
# 1                  1   177 Cross Rd, Westbourne Park SA 5041, Australia
# 2                  1   175 Cross Rd, Westbourne Park SA 5041, Australia
# 3                  2  Zone A Arndale Interchange - South side, Kilke...
# 4                  1           178 Cross Rd, Malvern SA 5061, Australia
#
#     latitude   longitude postcode             type  \
# 0 -34.966656  138.592148     5041   street_address
# 1 -34.966607  138.592301     5041   street_address
# 2 -34.966758  138.592715     5041   street_address
# 3 -34.875160  138.551628     5009  transit_station
# 4 -34.964960  138.611477     5061   street_address
#
#                                           route_desc  dist_from_centre  \
# 0  via Woodville Road, Holbrooks Road, Marion Roa...          5.180961
# 1  via Woodville Road, Holbrooks Road, Marion Roa...          5.172525
# 2  via Woodville Road, Holbrooks Road, Marion Roa...          5.180709
# 3  via Woodville Road, Holbrooks Road, Marion Roa...          7.057549
# 4  via Woodville Road, Holbrooks Road, Marion Roa...          4.900099
#
#    holiday_label
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0

# %%
df.isna().sum()
# Out:
# TripID                    0
# RouteID                   0
# StopID                    0
# StopName                  0
# WeekBeginning             0
# NumberOfBoardings         0
# formatted_address      3506
# latitude                  0
# longitude                 0
# postcode             425081
# type                      0
# route_desc                0
# dist_from_centre          0
# holiday_label             0
# dtype: int64

# %%
df['formatted_address'].value_counts()
# Out:
# Currie St, Adelaide SA 5000, Australia                                 228514
# North Terrace, Adelaide SA, Australia                                  212860
# King William Street, Adelaide SA 5000, Australia                       130862
# Pulteney St, Adelaide SA 5000, Australia                               103164
# Lower North East Rd, South Australia, Australia                         82044
#                                                                         ...
# 134 Justs Rd, Sellicks Beach SA 5174, Australia                             1
# Sir Ross Smith Ave & Lady Gowrie Dr, North Haven SA 5018, Australia         1
# 96 Alawoona Rd, Munno Para SA 5115, Australia                               1
# 51 Bains Rd, Morphett Vale SA 5162, Australia                               1
# 53 O'Sullivan Beach Rd, Lonsdale SA 5160, Australia                         1
# Name: formatted_address, Length: 3242, dtype: int64

# %%
df['formatted_address']=df['formatted_address'].fillna('others')

# %%
df.isna().sum()
# Out:
# TripID                    0
# RouteID                   0
# StopID                    0
# StopName                  0
# WeekBeginning             0
# NumberOfBoardings         0
# formatted_address         0
# latitude                  0
# longitude                 0
# postcode             425081
# type                      0
# route_desc                0
# dist_from_centre          0
# holiday_label             0
# dtype: int64

# %%
df['postcode'].value_counts()
# Out:
# 5000      1411185
# 5082       331917
# 5067.0     323928
# 5007       309843
# 5031       292905
#            ...
# 5600            2
# 5481            2
# 5031            1
# 2000            1
# 4123.0          1
# Name: postcode, Length: 259, dtype: int64

# %%
df.shape
# Out:
# (10857234, 14)

# %%
df.isna().sum()
# Out:
# TripID                    0
# RouteID                   0
# StopID                    0
# StopName                  0
# WeekBeginning             0
# NumberOfBoardings         0
# formatted_address         0
# latitude                  0
# longitude                 0
# postcode             425081
# type                      0
# route_desc                0
# dist_from_centre          0
# holiday_label             0
# dtype: int64

# %%
df[df['formatted_address']=='others']
# Out:
#           TripID RouteID  StopID    StopName WeekBeginning  NumberOfBoardings  \
# 1188313    46020     173   14765  25 Main Rd    2013-06-30                  6
# 1188381    46020     173   14765  25 Main Rd    2013-07-21                  6
# 1188387    46019     173   14765  25 Main Rd    2013-07-28                  2
# 1188439    46020     173   14765  25 Main Rd    2013-07-28                  6
# 1188465    46019     173   14765  25 Main Rd    2013-08-04                  1
# ...          ...     ...     ...         ...           ...                ...
# 7759240    57631     893   14766  25 Main Rd    2013-11-24                  3
# 7759253    57631     893   14766  25 Main Rd    2013-12-01                  2
# 7759362    18749     893   14766  25 Main Rd    2014-02-23                  1
# 7759380    18749     893   14766  25 Main Rd    2014-03-09                  2
# 10583165   25669  SCH_NS   14766  25 Main Rd    2013-08-25                  5
#
#          formatted_address   latitude   longitude postcode            type  \
# 1188313             others -35.003198  138.624529      NaN  street_address
# 1188381             others -35.003198  138.624529      NaN  street_address
# 1188387             others -35.003198  138.624529      NaN  street_address
# 1188439             others -35.003198  138.624529      NaN  street_address
# 1188465             others -35.003198  138.624529      NaN  street_address
# ...                    ...        ...         ...      ...             ...
# 7759240             others -35.003198  138.624529      NaN  street_address
# 7759253             others -35.003198  138.624529      NaN  street_address
# 7759362             others -35.003198  138.624529      NaN  street_address
# 7759380             others -35.003198  138.624529      NaN  street_address
# 10583165            others -35.003198  138.624529      NaN  street_address
#
#                                                  route_desc  dist_from_centre  \
# 1188313                                              others          9.291093
# 1188381                                              others          9.291093
# 1188387                                              others          9.291093
# 1188439                                              others          9.291093
# 1188465                                              others          9.291093
# ...                                                     ...               ...
# 7759240   via Stirling, Crafers, Upper Sturt Road & Bela...          9.291093
# 7759253   via Stirling, Crafers, Upper Sturt Road & Bela...          9.291093
# 7759362   via Stirling, Crafers, Upper Sturt Road & Bela...          9.291093
# 7759380   via Stirling, Crafers, Upper Sturt Road & Bela...          9.291093
# 10583165                                             others          9.291093
#
#           holiday_label
# 1188313               0
# 1188381               0
# 1188387               0
# 1188439               0
# 1188465               0
# ...                 ...
# 7759240               0
# 7759253               0
# 7759362               0
# 7759380               1
# 10583165              0
#
# [3506 rows x 14 columns]

# %%
cleaned=df.dropna()

# %%
cleaned.shape
# Out:
# (10432153, 14)

# %%
10857234-10432153
# Out:
# 425081

# %%
cleaned.isna().sum()
# Out:
# TripID               0
# RouteID              0
# StopID               0
# StopName             0
# WeekBeginning        0
# NumberOfBoardings    0
# formatted_address    0
# latitude             0
# longitude            0
# postcode             0
# type                 0
# route_desc           0
# dist_from_centre     0
# holiday_label        0
# dtype: int64

# %%
cleaned[cleaned['formatted_address']=='others']
# Out:
# Empty DataFrame
# Columns: [TripID, RouteID, StopID, StopName, WeekBeginning, NumberOfBoardings, formatted_address, latitude, longitude, postcode, type, route_desc, dist_from_centre, holiday_label]
# Index: []

# %%
cleaned.shape
# Out:
# (10432153, 14)

# %%
d=[]
for i in bb['StopName'].unique():
    d.append({'StopName': i,'Boarding_sum':np.sum(bb[bb['StopName'] == i]['NumberOfBoardings_sum'].pct_change())/54,
             'Boarding_count':np.sum(bb[bb['StopName'] == i]['NumberOfBoardings_count'].pct_change())/54,
             'Boarding_max':np.sum(bb[bb['StopName'] == i]['NumberOfBoardings_max'].pct_change())/54})
pct_chng = pd.DataFrame(d)

# %%
d
# Out:
# [{'StopName': '1 Anzac Hwy',
#   'Boarding_sum': 0.02017952098374666,
#   'Boarding_count': 0.004316654419509257,
#   'Boarding_max': 0.21809948911391325},
#  {'StopName': '1 Bartels Rd',
#   'Boarding_sum': 0.2819670902506825,
#   'Boarding_count': 0.19559959757005232,
#   'Boarding_max': 0.10838513338513339},
#  {'StopName': '1 Botanic Rd',
#   'Boarding_sum': 0.008743535042123607,
#   'Boarding_count': 0.0024244968893049304,
#   'Boarding_max': 0.14314360597377765},
#  {'StopName': '1 Frome Rd',
#   'Boarding_sum': 0.02829694137895626,
#   'Boarding_count': 0.004164816937506339,
#   'Boarding_max': 0.05907623891256239},
#  {'StopName': '1 Fullarton Rd',
#   'Boarding_sum': 0.3316984938174343,
#   'Boarding_count': 0.19588477366255144,
#   'Boarding_max': 0.22084435626102292},
#  {'StopName': '1 George St',
#   'Boarding_sum': 0.32847022126545095,
#   'Boarding_count': 0.20788698171691677,
#   'Boarding_max': 0.14924326700019735},
#  {'StopName': '1 Glen Osmond Rd',
#   'Boarding_sum': 0.019836899804176623,
#   'Boarding_count': 0.0030220521590154895,
#   'Boarding_max': 0.06154523111438575},
#  {'StopName': '1 Goodwood Rd',
#   'Boarding_sum': 0.02479605238092938,
#   'Boarding_count': 0.002254663825372863,
#   'Boarding_max': 0.0893772885757522},
#  {'StopName': '1 Henley Beach Rd',
#   'Boarding_sum': 0.03029302845925321,
#   'Boarding_count': -0.0024462251220539097,
#   'Boarding_max': 0.7456687196591716},
#  {'StopName': '1 Kensington Rd',
#   'Boarding_sum': 0.02234684974283642,
#   'Boarding_count': 0.008961203477857612,
#   'Boarding_max': 0.03703580672534921},
#  {'StopName': '1 King William Rd',
#   'Boarding_sum': 0.02798920685886593,
#   'Boarding_count': 0.0106936051627278,
#   'Boarding_max': 0.2132842242938059},
#  {'StopName': '1 Port Rd',
#   'Boarding_sum': 0.07016793927645033,
#   'Boarding_count': 0.024389019082759002,
#   'Boarding_max': 0.8344755706304962},
#  {'StopName': '1 Sir Donald Bradman Dr',
#   'Boarding_sum': 0.014838948162145286,
#   'Boarding_count': 0.006336613494735034,
#   'Boarding_max': 0.10841002049383777},
#  {'StopName': '1 Sir Edwin Smith Av',
#   'Boarding_sum': 0.2754793975866879,
#   'Boarding_count': 0.03910320639309345,
#   'Boarding_max': 1.1404478439482801},
#  {'StopName': '1 Unley Rd',
#   'Boarding_sum': 0.02336819307240985,
#   'Boarding_count': 0.008317689410371603,
#   'Boarding_max': 0.07949885723805361},
#  {'StopName': '10  Holbrooks Rd',
#   'Boarding_sum': 0.2450825061210134,
#   'Boarding_count': 0.0011209052089502123,
#   'Boarding_max': 1.3899931710474633},
#  {'StopName': '10  Marion Rd',
#   'Boarding_sum': 0.06640971322114866,
#   'Boarding_count': 0.020598067912076162,
#   'Boarding_max': 0.2904229680524719},
#  {'StopName': '10  Portrush Rd',
#   'Boarding_sum': 0.02310275979450831,
#   'Boarding_count': 0.0014069627906385148,
#   'Boarding_max': 0.0843109756524521},
#  {'StopName': '10 Airport Rd',
#   'Boarding_sum': 0.008608802516910694,
#   'Boarding_count': 0.0028839211553603555,
#   'Boarding_max': 0.0403646703864656},
#  {'StopName': '10 Anzac Hwy',
#   'Boarding_sum': 0.012862610616937895,
#   'Boarding_count': 0.0026116848592600116,
#   'Boarding_max': 0.2989449003497739},
#  {'StopName': '10 Ashley St',
#   'Boarding_sum': 0.010444755600484069,
#   'Boarding_count': -0.0028467296609241636,
#   'Boarding_max': 0.029233129590026736},
#  {'StopName': '10 Belair Rd',
#   'Boarding_sum': 0.026784068850592053,
#   'Boarding_count': 0.0049220249194058645,
#   'Boarding_max': 0.1262829848596304},
#  {'StopName': '10 Churchill Rd',
#   'Boarding_sum': 0.014498636765103372,
#   'Boarding_count': 0.0059111804787188894,
#   'Boarding_max': 0.046253426425210055},
#  {'StopName': '10 East Av',
#   'Boarding_sum': 0.00704155691145432,
#   'Boarding_count': -0.00040506720068647124,
#   'Boarding_max': 0.04844997222358103},
#  {'StopName': '10 Fullarton Rd',
#   'Boarding_sum': 0.027082601752491862,
#   'Boarding_count': -0.0005896557407075361,
#   'Boarding_max': 0.07714689931849392},
#  {'StopName': '10 Garden Tce',
#   'Boarding_sum': 0.11687905695046329,
#   'Boarding_count': 0.01368190285409194,
#   'Boarding_max': 0.4336525395524238},
#  {'StopName': '10 Glen Osmond Rd',
#   'Boarding_sum': 0.020443159112629554,
#   'Boarding_count': 0.00463926381920681,
#   'Boarding_max': 0.06518947598584551},
#  {'StopName': '10 Goodwood Rd',
#   'Boarding_sum': 0.036389881000828336,
#   'Boarding_count': 0.008189075460584281,
#   'Boarding_max': 0.09641792177120792},
#  {'StopName': '10 Greenhill Rd',
#   'Boarding_sum': 0.006361858201464715,
#   'Boarding_count': 0.0007604490026837816,
#   'Boarding_max': 0.03746396539251209},
#  {'StopName': '10 Harrow Tce',
#   'Boarding_sum': 0.01997626117203795,
#   'Boarding_count': 0.014504582215274502,
#   'Boarding_max': 0.03782393169648071},
#  {'StopName': '10 Harvey Av',
#   'Boarding_sum': 0.030700884142446917,
#   'Boarding_count': 0.009593692868833027,
#   'Boarding_max': 0.08502254787600509},
#  {'StopName': '10 Hawker St',
#   'Boarding_sum': 0.018452645259618827,
#   'Boarding_count': 0.006404680634128585,
#   'Boarding_max': 0.04932459515792851},
#  {'StopName': '10 Henley Beach Rd',
#   'Boarding_sum': 0.018999749262439306,
#   'Boarding_count': 0.0028386255343726386,
#   'Boarding_max': 0.08500096995304317},
#  {'StopName': '10 Kensington Rd',
#   'Boarding_sum': 0.037800064795650797,
#   'Boarding_count': 0.0031640427187848677,
#   'Boarding_max': 0.20439001173088706},
#  {'StopName': '10 Magill Rd',
#   'Boarding_sum': 0.006918472494915475,
#   'Boarding_count': 0.0028608901569273874,
#   'Boarding_max': 0.06358689478099522},
#  {'StopName': '10 Main North Rd',
#   'Boarding_sum': 0.023428129047971757,
#   'Boarding_count': 0.00820682889579191,
#   'Boarding_max': 0.05278406041248607},
#  {'StopName': '10 North East Rd',
#   'Boarding_sum': 0.08366000716749705,
#   'Boarding_count': 0.06946110160732984,
#   'Boarding_max': 0.14983833039388597},
#  {'StopName': '10 Payneham Rd',
#   'Boarding_sum': 0.011706457206943513,
#   'Boarding_count': 0.0013585493085471621,
#   'Boarding_max': 0.07783299003027076},
#  {'StopName': '10 Port Rd',
#   'Boarding_sum': 0.011336152021275107,
#   'Boarding_count': -0.000651826286479132,
#   'Boarding_max': 0.04686748436748436},
#  {'StopName': '10 Prospect Rd',
#   'Boarding_sum': 0.015234424573544111,
#   'Boarding_count': 0.0016289647492525943,
#   'Boarding_max': 0.06802004973508184},
#  {'StopName': '10 Sixth Av',
#   'Boarding_sum': 0.023402863191743353,
#   'Boarding_count': 0.008338376329142402,
#   'Boarding_max': 0.03083601697806913},
#  {'StopName': '10 Smith St',
#   'Boarding_sum': 0.019578994300640626,
#   'Boarding_count': 0.0038253468790185215,
#   'Boarding_max': 0.1452891701578712},
#  {'StopName': '10 South Rd',
#   'Boarding_sum': 0.0021967607673433714,
#   'Boarding_count': -0.004123814789147647,
#   'Boarding_max': 0.061404507499278733},
#  {'StopName': '10 Stirling St',
#   'Boarding_sum': 0.052386985156050586,
#   'Boarding_count': 0.011742419900873227,
#   'Boarding_max': 0.19383571221806517},
#  {'StopName': '10 The Parade',
#   'Boarding_sum': 0.012506966487248009,
#   'Boarding_count': 0.0010042393298170947,
#   'Boarding_max': 0.10334857455488257},
#  {'StopName': '10 Torrens Rd',
#   'Boarding_sum': 0.020893875584563397,
#   'Boarding_count': 0.006954597634492911,
#   'Boarding_max': 0.059685184213621297},
#  {'StopName': '10 Tusmore Av',
#   'Boarding_sum': 0.013810022256311626,
#   'Boarding_count': 0.0010845452222585743,
#   'Boarding_max': 0.04867558298579125},
#  {'StopName': '10 Victoria Av',
#   'Boarding_sum': 0.011807616249253208,
#   'Boarding_count': 0.010881913786693441,
#   'Boarding_max': 0.057384025439581016},
#  {'StopName': '10 Walkerville Tce',
#   'Boarding_sum': 0.01504939564764958,
#   'Boarding_count': 0.006524500369338448,
#   'Boarding_max': 0.0276481748703971},
#  {'StopName': '10 Winifred Av',
#   'Boarding_sum': 0.03424093808797912,
#   'Boarding_count': 0.015582303139997146,
#   'Boarding_max': 0.16044280876152223},
#  {'StopName': '100 Old Coach Rd',
#   'Boarding_sum': 0.02580404598000876,
#   'Boarding_count': 0.01606704734984639,
#   'Boarding_max': 0.06671132365576808},
#  {'StopName': '101 Port Rd',
#   'Boarding_sum': 0.4198344819668349,
#   'Boarding_count': 0.2641347849681183,
#   'Boarding_max': 0.2675925925925926},
#  {'StopName': '102 Murray St',
#   'Boarding_sum': 0.05713549525313783,
#   'Boarding_count': 0.029311159164979016,
#   'Boarding_max': 0.09648900482233815},
#  {'StopName': '102 Port Rd',
#   'Boarding_sum': 0.35993886184589663,
#   'Boarding_count': 0.2739587059031504,
#   'Boarding_max': 0.14845679012345678},
#  {'StopName': '107 Port Rd',
#   'Boarding_sum': 0.2977046298533227,
#   'Boarding_count': 0.24087897699008812,
#   'Boarding_max': 0.36323938407271744},
#  {'StopName': '107 Regency Rd',
#   'Boarding_sum': 0.08329321696106338,
#   'Boarding_count': 0.044886152034844834,
#   'Boarding_max': 0.1823285767730212},
#  {'StopName': '108 Port Rd',
#   'Boarding_sum': 0.12474352997013816,
#   'Boarding_count': 0.09707314290647627,
#   'Boarding_max': 0.15965608465608463},
#  {'StopName': '108 Regency Rd',
#   'Boarding_sum': 0.03071206235424406,
#   'Boarding_count': 0.023990023885983418,
#   'Boarding_max': 0.07676592954370734},
#  {'StopName': '109 Regency Rd',
#   'Boarding_sum': 0.4721661054994388,
#   'Boarding_count': 0.2631393298059964,
#   'Boarding_max': 0.36296296296296293},
#  {'StopName': '109 The Esplanade',
#   'Boarding_sum': 0.26853754531343116,
#   'Boarding_count': 0.24349124721931742,
#   'Boarding_max': 0.24613195446528782},
#  {'StopName': '10A  Marion Rd',
#   'Boarding_sum': 0.015476604329169563,
#   'Boarding_count': -0.0010629298571535853,
#   'Boarding_max': 0.13902509936733753},
#  {'StopName': '10A Coorara Av',
#   'Boarding_sum': 0.033702540801417116,
#   'Boarding_count': 0.007620674346070886,
#   'Boarding_max': 0.22710511629006463},
#  {'StopName': '10A Garden Tce',
#   'Boarding_sum': 0.03770296674847699,
#   'Boarding_count': 0.005092231874915167,
#   'Boarding_max': 0.0880825471488888},
#  {'StopName': '10A Harvey Av',
#   'Boarding_sum': 0.025487222769454494,
#   'Boarding_count': 0.01381626303303,
#   'Boarding_max': 0.051564748731501395},
#  {'StopName': '10A Sir Donald Bradman Dr',
#   'Boarding_sum': 0.010436328273122875,
#   'Boarding_count': 0.004513654111457272,
#   'Boarding_max': 0.06033253530816885},
#  {'StopName': '10A Smith St',
#   'Boarding_sum': 0.0854704837637857,
#   'Boarding_count': 0.02799239490274421,
#   'Boarding_max': 0.22535151632312883},
#  {'StopName': '11  Marion Rd',
#   'Boarding_sum': 0.0066560134291015136,
#   'Boarding_count': -0.002713255047623145,
#   'Boarding_max': 0.13697392631438127},
#  {'StopName': '11  Portrush Rd',
#   'Boarding_sum': 0.011610422920649477,
#   'Boarding_count': 0.0006339597538088804,
#   'Boarding_max': 0.10283323166371218},
#  {'StopName': '11 Anzac Hwy',
#   'Boarding_sum': 0.007439621159331309,
#   'Boarding_count': 0.0011577112245485788,
#   'Boarding_max': 0.05550442373637133},
#  {'StopName': '11 Ashley St',
#   'Boarding_sum': 0.02029869551606518,
#   'Boarding_count': 0.002524668188456871,
#   'Boarding_max': 0.09570039014483457},
#  {'StopName': '11 Belair Rd',
#   'Boarding_sum': 0.1594333236123809,
#   'Boarding_count': 0.009457421572581634,
#   'Boarding_max': 0.7457907741715819},
#  {'StopName': '11 Chitral Tce',
#   'Boarding_sum': 0.023769366010128135,
#   'Boarding_count': 0.01260494576683755,
#   'Boarding_max': 0.033083480305702545},
#  {'StopName': '11 Churchill Rd',
#   'Boarding_sum': 0.021857578080287637,
#   'Boarding_count': 0.008308977341917718,
#   'Boarding_max': 0.11956674071805878},
#  {'StopName': '11 Coorara Av',
#   'Boarding_sum': 0.03713069620794234,
#   'Boarding_count': 0.004431393986344575,
#   'Boarding_max': 0.06501922116602199},
#  {'StopName': '11 East Av',
#   'Boarding_sum': 0.01578149542843205,
#   'Boarding_count': 0.0034342627070880513,
#   'Boarding_max': 0.06285523040033328},
#  {'StopName': '11 Fullarton Rd',
#   'Boarding_sum': 0.02266564057439316,
#   'Boarding_count': 0.003906274440146166,
#   'Boarding_max': 0.3861895225084833},
#  {'StopName': '11 Glen Osmond Rd',
#   'Boarding_sum': 0.008791300580857173,
#   'Boarding_count': 0.005030868190368969,
#   'Boarding_max': 0.03264183189686526},
#  {'StopName': '11 Goodwood Rd',
#   'Boarding_sum': 0.020060375387163723,
#   'Boarding_count': 0.006105503605773109,
#   'Boarding_max': 0.0682815520233821},
#  {'StopName': '11 Greenhill Rd',
#   'Boarding_sum': 0.07584776306697077,
#   'Boarding_count': 0.052964165464165464,
#   'Boarding_max': 0.06815675262957682},
#  {'StopName': '11 Harrison Rd',
#   'Boarding_sum': 0.0075863933603341595,
#   'Boarding_count': 0.0005369470154394764,
#   'Boarding_max': 0.03137770695396383},
#  {'StopName': '11 Harrow Tce',
#   'Boarding_sum': 0.02551739101833875,
#   'Boarding_count': 0.014381571489840088,
#   'Boarding_max': 0.08187386778073052},
#  {'StopName': '11 Hawker St',
#   'Boarding_sum': 0.010004906637973139,
#   'Boarding_count': 0.0024310957977520665,
#   'Boarding_max': 0.03886337696191889},
#  {'StopName': '11 Henley Beach Rd',
#   'Boarding_sum': 0.016857337238800438,
#   'Boarding_count': 0.005166661643944821,
#   'Boarding_max': 0.03785158629717989},
#  {'StopName': '11 Kensington Rd',
#   'Boarding_sum': 0.047349517900814764,
#   'Boarding_count': 0.012854539774584782,
#   'Boarding_max': 0.08116800894578674},
#  {'StopName': '11 Magill Rd',
#   'Boarding_sum': 0.008624350460491951,
#   'Boarding_count': -0.00015504902237468206,
#   'Boarding_max': 0.042968004743030544},
#  {'StopName': '11 Main North Rd',
#   'Boarding_sum': 0.016158247258517874,
#   'Boarding_count': 0.0014841783880606974,
#   'Boarding_max': 0.0783862471727969},
#  {'StopName': '11 Mooringe Av',
#   'Boarding_sum': 0.03770258571345731,
#   'Boarding_count': 0.020586879959476032,
#   'Boarding_max': 0.1261380463457347},
#  {'StopName': '11 North East Rd',
#   'Boarding_sum': 0.01795433475879847,
#   'Boarding_count': 0.00571613122860463,
#   'Boarding_max': 0.07666678341342942},
#  {'StopName': '11 Payneham Rd',
#   'Boarding_sum': 0.012205851525154868,
#   'Boarding_count': 0.003773034130148357,
#   'Boarding_max': 0.09576914966061852},
#  {'StopName': '11 Port Rd',
#   'Boarding_sum': 0.008241761239095438,
#   'Boarding_count': 0.0038548691013778336,
#   'Boarding_max': 0.06116990005878896},
#  {'StopName': '11 Prospect Rd',
#   'Boarding_sum': 0.010316337950420532,
#   'Boarding_count': 0.0017510572641876248,
#   'Boarding_max': 0.05395616608020803},
#  {'StopName': '11 Sir Donald Bradman Dr',
#   'Boarding_sum': 0.023207702560086356,
#   'Boarding_count': 0.012286604233548805,
#   'Boarding_max': 0.17099305015971686},
#  {'StopName': '11 Sixth Av',
#   'Boarding_sum': 0.025062592992223773,
#   'Boarding_count': 0.012543103436109225,
#   'Boarding_max': 0.11702498556340456},
#  {'StopName': '11 Smith St',
#   'Boarding_sum': 0.017472196697018993,
#   'Boarding_count': 0.016116698632642548,
#   'Boarding_max': 0.04913701741187123},
#  {'StopName': '11 South Rd',
#   'Boarding_sum': 0.0007643787884920635,
#   'Boarding_count': 0.0007912268861565132,
#   'Boarding_max': 0.03932646571535459},
#  {'StopName': '11 Stirling St',
#   'Boarding_sum': 0.0644003719027823,
#   'Boarding_count': 0.02646917931470025,
#   'Boarding_max': 0.2060298754743199},
#  {'StopName': '11 Streeters Rd',
#   'Boarding_sum': 0.03273269567321586,
#   'Boarding_count': 0.0101646914959079,
#   'Boarding_max': 0.06052560844965984},
#  {'StopName': '11 The Parade',
#   'Boarding_sum': 0.02157294807200478,
#   'Boarding_count': -0.0009584807837029958,
#   'Boarding_max': 0.09497471636151476},
#  {'StopName': '11 Tusmore Av',
#   'Boarding_sum': 0.023789931261869752,
#   'Boarding_count': 0.009904611508565165,
#   'Boarding_max': 0.03582273236771001},
#  {'StopName': '11 Walkerville Tce',
#   'Boarding_sum': 0.025573685249420525,
#   'Boarding_count': 0.009792901785994622,
#   'Boarding_max': 0.06051587301587301},
#  {'StopName': '11 White Av',
#   'Boarding_sum': 0.032022073528095635,
#   'Boarding_count': 0.011102822401637007,
#   'Boarding_max': 0.07238649611800627},
#  {'StopName': '110 Haines Rd',
#   'Boarding_sum': 0.14597900406870604,
#   'Boarding_count': 0.059002057613168735,
#   'Boarding_max': 0.29154906307684086},
#  {'StopName': '110 The Esplanade',
#   'Boarding_sum': 0.23585415700646453,
#   'Boarding_count': 0.14854782563115895,
#   'Boarding_max': 0.21574074074074076},
#  {'StopName': '111 Haines Rd',
#   'Boarding_sum': 0.1775639129078541,
#   'Boarding_count': 0.07268384907273795,
#   'Boarding_max': 0.2297772700550478},
#  {'StopName': '111 Regency Rd',
#   'Boarding_sum': 0.02343590230771684,
#   'Boarding_count': -0.0005493574140846567,
#   'Boarding_max': 0.08552243697084244},
#  {'StopName': '112 Dawkins Av',
#   'Boarding_sum': 0.1418691181698578,
#   'Boarding_count': 0.10690035273368605,
#   'Boarding_max': 0.08024691358024691},
#  {'StopName': '112 Regency Rd',
#   'Boarding_sum': 0.18985348312073677,
#   'Boarding_count': 0.17688055830255692,
#   'Boarding_max': 0.11795267489711933},
#  {'StopName': '112 Rowley Rd',
#   'Boarding_sum': 0.050259466973050226,
#   'Boarding_count': 0.03361773037904881,
#   'Boarding_max': 0.12745777884666773},
#  {'StopName': '113 Regency Rd',
#   'Boarding_sum': 0.013592993728841764,
#   'Boarding_count': 0.0019741184925921623,
#   'Boarding_max': 0.045060443671554797},
#  {'StopName': '114 Dawkins Av',
#   'Boarding_sum': 0.27045053711720374,
#   'Boarding_count': 0.2135435038212816,
#   'Boarding_max': 0.13055555555555556},
#  {'StopName': '114 Regency Rd',
#   'Boarding_sum': 0.029077898181777088,
#   'Boarding_count': 0.0052676849064797315,
#   'Boarding_max': 0.0821983983605669},
#  {'StopName': '114A Pridham Bvd',
#   'Boarding_sum': 0.0291987723065566,
#   'Boarding_count': 0.019162539120365057,
#   'Boarding_max': 0.0766447544225322},
#  {'StopName': '115 Regency Rd',
#   'Boarding_sum': 0.10661408343087132,
#   'Boarding_count': 0.04214213321573406,
#   'Boarding_max': 0.0763920100908405},
#  {'StopName': '116 Pridham Bvd',
#   'Boarding_sum': 0.006165657147647903,
#   'Boarding_count': -0.0013673666279215846,
#   'Boarding_max': 0.05718662579425084},
#  {'StopName': '116 Regency Rd',
#   'Boarding_sum': 0.01050783785769213,
#   'Boarding_count': 0.002020886113049968,
#   'Boarding_max': 0.04230292371632241},
#  {'StopName': '117 Osprey Pde',
#   'Boarding_sum': 0.113822579240243,
#   'Boarding_count': 0.09842739564961785,
#   'Boarding_max': 0.08207671957671961},
#  {'StopName': '117 Rowley Rd',
#   'Boarding_sum': 0.029344426839769597,
#   'Boarding_count': 0.015303158568398527,
#   'Boarding_max': 0.08128075269179334},
#  {'StopName': '118 BUTTERWORTH Rd',
#   'Boarding_sum': 0.09162893362932606,
#   'Boarding_count': 0.030391422061080003,
#   'Boarding_max': 0.2214550881217548},
#  {'StopName': '119 BUTTERWORTH Rd',
#   'Boarding_sum': 0.060379317766088375,
#   'Boarding_count': 0.04113029266842775,
#   'Boarding_max': 0.12420634920634918},
#  {'StopName': '11A  Marion Rd',
#   'Boarding_sum': 0.008292162209486765,
#   'Boarding_count': -0.0010355118263466734,
#   'Boarding_max': 0.09784366507627906},
#  {'StopName': '11A Streeters Rd',
#   'Boarding_sum': 0.01563938617467617,
#   'Boarding_count': 0.0021219237523177068,
#   'Boarding_max': 0.034869721447378814},
#  {'StopName': '12  Portrush Rd',
#   'Boarding_sum': 0.014080200993422136,
#   'Boarding_count': 1.7096718579548112e-05,
#   'Boarding_max': 0.04230217002821347},
#  {'StopName': '12 Anzac Hwy',
#   'Boarding_sum': 0.014991968213716615,
#   'Boarding_count': 0.006761075228527706,
#   'Boarding_max': 0.05425713538458637},
#  {'StopName': '12 Ashley St',
#   'Boarding_sum': 0.08215112513061625,
#   'Boarding_count': 0.0038352781499559423,
#   'Boarding_max': 0.5361918840698287},
#  {'StopName': '12 Belair Rd',
#   'Boarding_sum': 0.012640882894324761,
#   'Boarding_count': -0.00048124804488707755,
#   'Boarding_max': 0.1537375524158472},
#  {'StopName': '12 Chitral Tce',
#   'Boarding_sum': 0.022587037402742215,
#   'Boarding_count': 0.008173043133034652,
#   'Boarding_max': 0.047837810337810344},
#  {'StopName': '12 Churchill Rd',
#   'Boarding_sum': 0.015269930634044495,
#   'Boarding_count': 0.006741064744962415,
#   'Boarding_max': 0.07956271347811468},
#  {'StopName': '12 Coorara Av',
#   'Boarding_sum': 0.01968232169718212,
#   'Boarding_count': 0.0017732591540495183,
#   'Boarding_max': 0.05845115625609255},
#  {'StopName': '12 East Av',
#   'Boarding_sum': 0.12344235733518642,
#   'Boarding_count': 0.013307745222858687,
#   'Boarding_max': 0.4283513685892993},
#  {'StopName': '12 Fullarton Rd',
#   'Boarding_sum': 0.022871560202026985,
#   'Boarding_count': -0.0003732971828449602,
#   'Boarding_max': 0.1324064288334696},
#  {'StopName': '12 Glen Osmond Rd',
#   'Boarding_sum': 0.0143296275999695,
#   'Boarding_count': 0.004163643719636108,
#   'Boarding_max': 0.10208162943729394},
#  {'StopName': '12 Goodwood Rd',
#   'Boarding_sum': 0.011325319293723192,
#   'Boarding_count': 0.0046667570084091715,
#   'Boarding_max': 0.04327145331149907},
#  {'StopName': '12 Grange Rd',
#   'Boarding_sum': 0.008794133334875257,
#   'Boarding_count': 0.0021902393069945236,
#   'Boarding_max': 0.06937237974424354},
#  {'StopName': '12 Greenhill Rd',
#   'Boarding_sum': 0.06191541292959855,
#   'Boarding_count': 0.03285675230119675,
#   'Boarding_max': 0.04406418264636559},
#  {'StopName': '12 Harrison Rd',
#   'Boarding_sum': 0.0029094571969364323,
#   'Boarding_count': -0.0006163905607933043,
#   'Boarding_max': 0.02192889295787472},
#  {'StopName': '12 Harrow Tce',
#   'Boarding_sum': 0.016758949610693144,
#   'Boarding_count': 0.0054518966979627305,
#   'Boarding_max': 0.04686378687823852},
#  {'StopName': '12 Hawker St',
#   'Boarding_sum': 0.010793727800793504,
#   'Boarding_count': 0.0009192214934481803,
#   'Boarding_max': 0.03554208800597795},
#  {'StopName': '12 Henley Beach Rd',
#   'Boarding_sum': 0.009591502494254627,
#   'Boarding_count': 1.0910744920219937e-06,
#   'Boarding_max': 0.06193214991646242},
#  {'StopName': '12 Hilda Tce',
#   'Boarding_sum': 0.008298006852565145,
#   'Boarding_count': 0.004508341185781189,
#   'Boarding_max': 0.05788852359134361},
#  {'StopName': '12 Kensington Rd',
#   'Boarding_sum': 0.02418733011144352,
#   'Boarding_count': 0.007257244204078927,
#   'Boarding_max': 0.12124648449843632},
#  {'StopName': '12 Magill Rd',
#   'Boarding_sum': 0.01574749337513955,
#   'Boarding_count': 0.0030783590246565335,
#   'Boarding_max': 0.04539012201980897},
#  {'StopName': '12 Main North Rd',
#   'Boarding_sum': 0.012002726200594041,
#   'Boarding_count': -0.0002864150107467972,
#   'Boarding_max': 0.04813730330688655},
#  {'StopName': '12 Marion Rd',
#   'Boarding_sum': 0.013970978238393396,
#   'Boarding_count': -7.605689336742044e-05,
#   'Boarding_max': 0.07476828575684784},
#  {'StopName': '12 Mooringe Av',
#   'Boarding_sum': 0.05051293822475734,
#   'Boarding_count': 0.015268809377350426,
#   'Boarding_max': 0.11320655746796972},
#  {'StopName': '12 North East Rd',
#   'Boarding_sum': 0.009960184565485893,
#   'Boarding_count': 0.009292471043548136,
#   'Boarding_max': 0.11378600823045265},
#  {'StopName': '12 Northumberland St',
#   'Boarding_sum': 0.06164122208679338,
#   'Boarding_count': 0.03478600421613414,
#   'Boarding_max': 0.10422643200420978},
#  {'StopName': '12 Payneham Rd',
#   'Boarding_sum': 0.0100128769466345,
#   'Boarding_count': -0.00046526915926030317,
#   'Boarding_max': 0.0574197806446648},
#  {'StopName': '12 Pierson St',
#   'Boarding_sum': 0.023197146683004464,
#   'Boarding_count': -0.002007721241423693,
#   'Boarding_max': 0.07392213595316904},
#  {'StopName': '12 Port Rd',
#   'Boarding_sum': 0.006417529045639365,
#   'Boarding_count': 0.002796828226014415,
#   'Boarding_max': 0.04029411946078612},
#  {'StopName': '12 Prospect Rd',
#   'Boarding_sum': 0.01453939734495959,
#   'Boarding_count': 0.0032354390340054184,
#   'Boarding_max': 0.036600093849324826},
#  {'StopName': '12 Sir Donald Bradman Dr',
#   'Boarding_sum': 0.03498993067678663,
#   'Boarding_count': 0.031146522553682082,
#   'Boarding_max': 0.10287682542584502},
#  {'StopName': '12 Sixth Av',
#   'Boarding_sum': 0.020024955010783007,
#   'Boarding_count': 0.00781250563460001,
#   'Boarding_max': 0.054251589746710245},
#  {'StopName': '12 South Rd',
#   'Boarding_sum': 0.01515807253612224,
#   'Boarding_count': 0.005442336183924327,
#   'Boarding_max': 0.05246412084647378},
#  {'StopName': '12 Streeters Rd',
#   'Boarding_sum': 0.02110688897767666,
#   'Boarding_count': 0.012853459575800799,
#   'Boarding_max': 0.07007668257668256},
#  {'StopName': '12 The Parade',
#   'Boarding_sum': 0.0058796721122878585,
#   'Boarding_count': -0.0010948420567798414,
#   'Boarding_max': 0.053078558756663334},
#  {'StopName': '12 Tusmore Av',
#   'Boarding_sum': 0.023314142070867284,
#   'Boarding_count': 0.004374416755370972,
#   'Boarding_max': 0.0593592239878939},
#  {'StopName': '12 Walkerville Tce',
#   'Boarding_sum': 0.019105538163980893,
#   'Boarding_count': 0.00688925883283179,
#   'Boarding_max': 0.050764410486632716},
#  {'StopName': '12 Winston Av',
#   'Boarding_sum': 0.009140325478302668,
#   'Boarding_count': 0.0018013907554698056,
#   'Boarding_max': 0.08324531982936427},
#  {'StopName': '120 BUTTERWORTH Rd',
#   'Boarding_sum': 0.031609004132538546,
#   'Boarding_count': 0.015770752192521848,
#   'Boarding_max': 0.17269803782961682},
#  {'StopName': '120 Jabiru Pde',
#   'Boarding_sum': 0.21363127613127617,
#   'Boarding_count': 0.14184303350970018,
#   'Boarding_max': 0.22059082892416224},
#  {'StopName': '121 Croser Av',
#   'Boarding_sum': 0.24267288447070007,
#   'Boarding_count': 0.129345962679296,
#   'Boarding_max': 0.1842592592592593},
#  {'StopName': '121 Explorer Pde',
#   'Boarding_sum': 0.592212974096029,
#   'Boarding_count': 0.22843180482069372,
#   'Boarding_max': 0.37467100800434133},
#  {'StopName': '122 Croser Av',
#   'Boarding_sum': 0.05451758537638179,
#   'Boarding_count': 0.02065548759813103,
#   'Boarding_max': 0.07309593698482589},
#  {'StopName': '122 High St',
#   'Boarding_sum': 0.06021689902820393,
#   'Boarding_count': 0.026763668430335102,
#   'Boarding_max': 0.10332424776869219},
#  {'StopName': '122A ALDINGA BEACH Rd',
#   'Boarding_sum': 0.04464426164321018,
#   'Boarding_count': 0.03300356825280794,
#   'Boarding_max': 0.09298855344606978},
#  {'StopName': '123 Main North Rd',
#   'Boarding_sum': 0.13807946622489103,
#   'Boarding_count': 0.1608171663727219,
#   'Boarding_max': 0.1750708139597028},
#  {'StopName': '124 Lyndoch Rd',
#   'Boarding_sum': 0.10198446920583144,
#   'Boarding_count': 0.06412445579112247,
#   'Boarding_max': 0.16867283950617282},
#  {'StopName': '124 Storey Av',
#   'Boarding_sum': 0.051873540879101294,
#   'Boarding_count': 0.03451424323183024,
#   'Boarding_max': 0.1803806942225617},
#  {'StopName': '126 Muller Rd',
#   'Boarding_sum': 0.04899654924998882,
#   'Boarding_count': 0.015765106699632145,
#   'Boarding_max': 0.07732274398511067},
#  {'StopName': '126A Muller Rd',
#   'Boarding_sum': 0.021235693075641247,
#   'Boarding_count': 0.002285869743682011,
#   'Boarding_max': 0.07338238085415327},
#  {'StopName': '127 Lyndoch Rd',
#   'Boarding_sum': 0.22007642563198124,
#   'Boarding_count': 0.13734567901234568,
#   'Boarding_max': 0.2003086419753086},
#  {'StopName': '127 The Esplanade',
#   'Boarding_sum': 0.159942115497671,
#   'Boarding_count': 0.0879041740152851,
#   'Boarding_max': 0.17716049382716045},
#  {'StopName': '12A Burbridge Rd',
#   'Boarding_sum': 0.06616357881414486,
#   'Boarding_count': 0.03819379007764239,
#   'Boarding_max': 0.08069718347496124},
#  {'StopName': '12A Greenhill Rd',
#   'Boarding_sum': 0.09735315417934151,
#   'Boarding_count': 0.054614932392710154,
#   'Boarding_max': 0.11259179675091041},
#  {'StopName': '12A Streeters Rd',
#   'Boarding_sum': 0.30656354357334753,
#   'Boarding_count': 0.21166426166426167,
#   'Boarding_max': 0.14506172839506173},
#  {'StopName': '12B Burbridge Rd',
#   'Boarding_sum': 0.04367458557904848,
#   'Boarding_count': 0.017997963295792466,
#   'Boarding_max': 0.12537811982256428},
#  {'StopName': '12C Burbridge Rd',
#   'Boarding_sum': 0.00018404764162665093,
#   'Boarding_count': 0.00017316348517563922,
#   'Boarding_max': 0.03953580559851405},
#  {'StopName': '12D Davis St',
#   'Boarding_sum': 0.07874251487004999,
#   'Boarding_count': 0.03912672899601004,
#   'Boarding_max': 0.12218948746726523},
#  {'StopName': '13  Holbrooks Rd',
#   'Boarding_sum': 0.03861681841246646,
#   'Boarding_count': 0.01476363543742378,
#   'Boarding_max': 0.08568737127246562},
#  {'StopName': '13  Payneham Rd',
#   'Boarding_sum': 0.008201722349625792,
#   'Boarding_count': -0.0019319357261064444,
#   'Boarding_max': 0.07263453624863463},
#  {'StopName': '13  Portrush Rd',
#   'Boarding_sum': 0.05273038021162921,
#   'Boarding_count': 0.0015834027402957087,
#   'Boarding_max': 0.2140133855774056},
#  {'StopName': '13  Rowells Rd',
#   'Boarding_sum': 0.03710021172245121,
#   'Boarding_count': 0.019605252193445104,
#   'Boarding_max': 0.09573045267489712},
#  {'StopName': '13 Anzac Hwy',
#   'Boarding_sum': 0.016258223891996534,
#   'Boarding_count': 0.0022081374896980362,
#   'Boarding_max': 0.05264193159836734},
#  {'StopName': '13 Belair Rd',
#   'Boarding_sum': 0.008001660032783475,
#   'Boarding_count': -0.0019329621954278602,
#   'Boarding_max': 0.07500626020367569},
#  {'StopName': '13 Churchill Rd',
#   'Boarding_sum': 0.007509563702803125,
#   'Boarding_count': 0.00013319998145468038,
#   'Boarding_max': 0.05086446475335365},
#  {'StopName': '13 Coorara Av',
#   'Boarding_sum': 0.011648822488489054,
#   'Boarding_count': 0.0010525282776471594,
#   'Boarding_max': 0.024436492567088623},
#  {'StopName': '13 David Tce',
#   'Boarding_sum': 0.13731551068152376,
#   'Boarding_count': 0.11824661963550852,
#   'Boarding_max': 0.08117283950617285},
#  {'StopName': '13 Fullarton Rd',
#   'Boarding_sum': 0.35420087193766964,
#   'Boarding_count': 0.09764180920912796,
#   'Boarding_max': 0.3989239216719369},
#  {'StopName': '13 Glen Osmond Rd',
#   'Boarding_sum': 0.01823300301828144,
#   'Boarding_count': 0.0004485137518350162,
#   'Boarding_max': 0.3296003299903977},
#  {'StopName': '13 Goodwood Rd',
#   'Boarding_sum': 0.02447611272958971,
#   'Boarding_count': 0.0039980263836722095,
#   'Boarding_max': 0.12856524610520298},
#  {'StopName': '13 Grange Rd',
#   'Boarding_sum': 0.004303495513113347,
#   'Boarding_count': 0.00032704390475626384,
#   'Boarding_max': 0.03519276766863177},
#  {'StopName': '13 Greenhill Rd',
#   'Boarding_sum': 0.05608282532707302,
#   'Boarding_count': 0.05040615248948583,
#   'Boarding_max': 0.12308799189080667},
#  {'StopName': '13 Harrison Rd',
#   'Boarding_sum': 0.014039921122436546,
#   'Boarding_count': 0.004056394147947385,
#   'Boarding_max': 0.055476359111325674},
#  {'StopName': '13 Hawker St',
#   'Boarding_sum': 0.005237026552461614,
#   'Boarding_count': 0.0029886821479835736,
#   'Boarding_max': 0.044028253130432786},
#  {'StopName': '13 Henley Beach Rd',
#   'Boarding_sum': 0.00384077576811488,
#   'Boarding_count': -0.000924740440935827,
#   'Boarding_max': 0.05869336229636632},
#  {'StopName': '13 Hilda Tce',
#   'Boarding_sum': 0.05153668450227086,
#   'Boarding_count': 0.04762136012136014,
#   'Boarding_max': 0.14942680776014108},
#  {'StopName': '13 Ingerson St',
#   'Boarding_sum': 0.10668327637319276,
#   'Boarding_count': 0.06915748860193308,
#   'Boarding_max': 0.2003953351175573},
#  {'StopName': '13 Kensington Rd',
#   'Boarding_sum': 0.027927523761602967,
#   'Boarding_count': 0.009377026629467275,
#   'Boarding_max': 0.07035044347350848},
#  {'StopName': '13 Magill Rd',
#   'Boarding_sum': 0.007143157016682411,
#   'Boarding_count': 0.0014496663938609352,
#   'Boarding_max': 0.03618260050766332},
#  {'StopName': '13 Main North Rd',
#   'Boarding_sum': 0.02129577123914203,
#   'Boarding_count': 0.005413153452813757,
#   'Boarding_max': 0.07603252543088582},
#  {'StopName': '13 Marion Rd',
#   'Boarding_sum': 0.020748618000863625,
#   'Boarding_count': 0.0032205281008969456,
#   'Boarding_max': 0.261210053356505},
#  {'StopName': '13 Military Rd',
#   'Boarding_sum': 0.02464322073841749,
#   'Boarding_count': 0.010097955053500194,
#   'Boarding_max': 0.054137615768947926},
#  {'StopName': '13 Mooringe Av',
#   'Boarding_sum': 0.018158662452201043,
#   'Boarding_count': 0.0011144432862440407,
#   'Boarding_max': 0.20383956614828505},
#  {'StopName': '13 North East Rd',
#   'Boarding_sum': 0.010815698911264356,
#   'Boarding_count': 0.004236961130115357,
#   'Boarding_max': 0.09538621214801869},
#  {'StopName': '13 Northumberland St',
#   'Boarding_sum': 0.04866368435498024,
#   'Boarding_count': 0.021206804744197824,
#   'Boarding_max': 0.09957979263534816},
#  {'StopName': '13 Port Rd',
#   'Boarding_sum': 0.007751012863981031,
#   'Boarding_count': 0.001940442603739913,
#   'Boarding_max': 0.07348861252841633},
#  {'StopName': '13 Prospect Rd',
#   'Boarding_sum': 0.016100328593284516,
#   'Boarding_count': 0.0018737675671074408,
#   'Boarding_max': 0.04218214989557153},
#  {'StopName': '13 Rochester St',
#   'Boarding_sum': 0.03190245583830834,
#   'Boarding_count': 0.012611465573310157,
#   'Boarding_max': 0.09811030019363355},
#  {'StopName': '13 Sixth Av',
#   'Boarding_sum': 0.012222805537747594,
#   'Boarding_count': 0.009506609948900128,
#   'Boarding_max': 0.0302755960503768},
#  {'StopName': '13 South Rd',
#   'Boarding_sum': 0.01052404213356133,
#   'Boarding_count': 0.0017175593851712695,
#   'Boarding_max': 0.05628369893571207},
#  {'StopName': '13 South Tce',
#   'Boarding_sum': 0.048747116699184,
#   'Boarding_count': 0.03387775800564779,
#   'Boarding_max': 0.07145796590241034},
#  {'StopName': '13 Sussex Tce',
#   'Boarding_sum': 0.0024659802816947695,
#   'Boarding_count': 0.0023146007138796056,
#   'Boarding_max': 0.05245145649557415},
#  {'StopName': '13 The Parade',
#   'Boarding_sum': 0.07125942533150423,
#   'Boarding_count': 0.0049022183064924936,
#   'Boarding_max': 0.28983394458125716},
#  {'StopName': '13 Towers Tce',
#   'Boarding_sum': 0.020015739548866516,
#   'Boarding_count': 0.0074181529398746025,
#   'Boarding_max': 0.05239452859120905},
#  {'StopName': '13 Tutt Av',
#   'Boarding_sum': 2.6781864174857968,
#   'Boarding_count': 0.15352890875766695,
#   'Boarding_max': 2.2734095645836865},
#  {'StopName': '13 Tutt Ave',
#   'Boarding_sum': 0.04112217209863847,
#   'Boarding_count': 0.006362197216834564,
#   'Boarding_max': 0.20385559655918778},
#  {'StopName': '13 Vale St',
#   'Boarding_sum': 0.014745570242605885,
#   'Boarding_count': 0.006189526117729786,
#   'Boarding_max': 0.03865572632512957},
#  {'StopName': '13 Winston Av',
#   'Boarding_sum': 0.025020769194983222,
#   'Boarding_count': 0.003182023589161486,
#   'Boarding_max': 0.06789311964965561},
#  {'StopName': '130 Norman Rd',
#   'Boarding_sum': 0.10006922767878332,
#   'Boarding_count': 0.08166103443881223,
#   'Boarding_max': 0.18771310993533216},
#  {'StopName': '133 Monaco Bvd',
#   'Boarding_sum': 0.22845026698325382,
#   'Boarding_count': 0.13042975542975543,
#   'Boarding_max': 0.2664609053497943},
#  {'StopName': '134 O G Rd',
#   'Boarding_sum': 0.054920957626855345,
#   'Boarding_count': 0.018383215416464767,
#   'Boarding_max': 0.16984123372582272},
#  {'StopName': '135 Carlton Rd',
#   'Boarding_sum': 0.21224566372485187,
#   'Boarding_count': 0.09362607557052002,
#   'Boarding_max': 0.3166887125220459},
#  {'StopName': '135 O G Rd',
#   'Boarding_sum': 0.07029647397567051,
#   'Boarding_count': 0.03142287104821349,
#   'Boarding_max': 0.09750594056149611},
#  {'StopName': '137 Perth St',
#   'Boarding_sum': 0.35052561642480384,
#   'Boarding_count': 0.10767262572818127,
#   'Boarding_max': 0.7740819042037578},
#  {'StopName': '137 Portrush Rd',
#   'Boarding_sum': 0.0424189589905189,
#   'Boarding_count': 0.020027953678827096,
#   'Boarding_max': 0.06515053056805721},
#  {'StopName': '138 Portrush Rd',
#   'Boarding_sum': 0.04056598766003395,
#   'Boarding_count': 0.015506295356668498,
#   'Boarding_max': 0.1297017797017797},
#  {'StopName': '139 Portrush Rd',
#   'Boarding_sum': 0.0994857624995039,
#   'Boarding_count': 0.045741054346563906,
#   'Boarding_max': 0.17678181326057146},
#  {'StopName': '13A  Rowells Rd',
#   'Boarding_sum': 0.1183425966052552,
#   'Boarding_count': 0.05650251464477993,
#   'Boarding_max': 0.18384773662551443},
#  {'StopName': '13A Addison Av',
#   'Boarding_sum': 0.007765596260073167,
#   'Boarding_count': 0.007402830848542413,
#   'Boarding_max': 0.028160801771115625},
#  {'StopName': '13A Grange Rd',
#   'Boarding_sum': 0.3895452162863184,
#   'Boarding_count': 0.17354430548874994,
#   'Boarding_max': 0.5967309260787521},
#  {'StopName': '13A Greenhill Rd',
#   'Boarding_sum': 0.2039214673389179,
#   'Boarding_count': 0.061521092076647625,
#   'Boarding_max': 0.17423769964189642},
#  {'StopName': '13A Military Rd',
#   'Boarding_sum': 0.01822517691367706,
#   'Boarding_count': 0.006130311285592819,
#   'Boarding_max': 0.05065501484105148},
#  {'StopName': '13A Northern Av',
#   'Boarding_sum': 0.19330440649885092,
#   'Boarding_count': 0.1600161669606114,
#   'Boarding_max': 0.35154320987654325},
#  {'StopName': '13A Payneham Rd',
#   'Boarding_sum': 0.01475215469816337,
#   'Boarding_count': 0.00522633691533498,
#   'Boarding_max': 0.04461570644061185},
#  {'StopName': '13A Stonehouse Av',
#   'Boarding_sum': 0.03267056582757023,
#   'Boarding_count': 0.012052549757131777,
#   'Boarding_max': 0.08815736732403395},
#  {'StopName': '13A Towers Tce',
#   'Boarding_sum': 0.016765710342574375,
#   'Boarding_count': 0.007413151084017779,
#   'Boarding_max': 0.05691905767155166},
#  {'StopName': '13B Addison Av',
#   'Boarding_sum': 0.3196413431954902,
#   'Boarding_count': 0.041273441518539566,
#   'Boarding_max': 1.0077895819112375},
#  {'StopName': '13B Grange Rd',
#   'Boarding_sum': 0.08146927021913444,
#   'Boarding_count': 0.03779752975846607,
#   'Boarding_max': 0.1978412164820348},
#  {'StopName': '13B Northern Av',
#   'Boarding_sum': 0.13854082044581384,
#   'Boarding_count': 0.10125116652894431,
#   'Boarding_max': 0.256526703748926},
#  {'StopName': '13B Simcock St',
#   'Boarding_sum': 0.03544111106061188,
#   'Boarding_count': 0.0268238887249783,
#   'Boarding_max': 0.10789063614786008},
#  {'StopName': '13C Broad St',
#   'Boarding_sum': 0.05764888179805587,
#   'Boarding_count': 0.09253072030849807,
#   'Boarding_max': 0.06785380257602482},
#  {'StopName': '13C Cambridge Av',
#   'Boarding_sum': 0.028334423115025074,
#   'Boarding_count': 0.011898304627461056,
#   'Boarding_max': 0.05684385335387039},
#  {'StopName': '13C Grange Rd',
#   'Boarding_sum': 0.05221292575064779,
#   'Boarding_count': 0.03443736489402124,
#   'Boarding_max': 0.09433144016477349},
#  {'StopName': '13D Grange Rd',
#   'Boarding_sum': 0.032555662057287375,
#   'Boarding_count': 0.011331461541530443,
#   'Boarding_max': 0.12935773074661963},
#  {'StopName': '13D Lower Portrush Road',
#   'Boarding_sum': 0.20725771054933417,
#   'Boarding_count': 0.13858738997627887,
#   'Boarding_max': 0.23633156966490299},
#  {'StopName': '13E Ascot Ave',
#   'Boarding_sum': 0.06936356533165586,
#   'Boarding_count': 0.03340720493498272,
#   'Boarding_max': 0.0994782480893592},
#  {'StopName': '13E Grange Rd',
#   'Boarding_sum': 0.07379673255392626,
#   'Boarding_count': 0.05754569051137679,
#   'Boarding_max': 0.15318930041152262},
#  {'StopName': '14  Portrush Rd',
#   'Boarding_sum': 0.030744144886164684,
#   'Boarding_count': 0.01067959449878363,
#   'Boarding_max': 0.10572884471451872},
#  {'StopName': '14 Adelaide Crafers Hwy',
#   'Boarding_sum': 0.0719196282357661,
#   'Boarding_count': 0.004855848320516149,
#   'Boarding_max': 0.11247686939200613},
#  {'StopName': '14 Anzac Hwy',
#   'Boarding_sum': 0.014861495258699174,
#   'Boarding_count': 0.004764908678428357,
#   'Boarding_max': 0.0616055955962628},
#  {'StopName': '14 Belair Rd',
#   'Boarding_sum': -0.011317444866052032,
#   'Boarding_count': -0.0108055104913048,
#   'Boarding_max': 0.041731256594237244},
#  {'StopName': '14 Churchill Rd',
#   'Boarding_sum': 0.01245892617548851,
#   'Boarding_count': 0.0012193437467095895,
#   'Boarding_max': 0.11440994025773457},
#  {'StopName': '14 David Tce',
#   'Boarding_sum': 0.40728849339960443,
#   'Boarding_count': 0.2714726631393298,
#   'Boarding_max': 0.13549382716049382},
#  {'StopName': '14 Devereux Rd',
#   'Boarding_sum': 0.016515413310043345,
#   'Boarding_count': 0.00836494434545432,
#   'Boarding_max': 0.05319087230851937},
#  {'StopName': '14 Fullarton Rd',
#   'Boarding_sum': 0.03086721334909508,
#   'Boarding_count': 0.003416549238948755,
#   'Boarding_max': 0.10806478989079832},
#  {'StopName': '14 Gage St',
#   'Boarding_sum': 0.067469342366345,
#   'Boarding_count': 0.021613332015717454,
#   'Boarding_max': 0.10262345679012348},
#  {'StopName': '14 Galway Av',
#   'Boarding_sum': 0.021441311817301217,
#   'Boarding_count': 0.006301873052171377,
#   'Boarding_max': 0.07739597857969889},
#  {'StopName': '14 Goodwood Rd',
#   'Boarding_sum': 0.008992888441812041,
#   'Boarding_count': 0.0009448194370991985,
#   'Boarding_max': 0.03515434545706303},
#  {'StopName': '14 Grange Rd',
#   'Boarding_sum': 0.023156180950188048,
#   'Boarding_count': 0.0022890835788677835,
#   'Boarding_max': 0.48563396867732894},
#  {'StopName': '14 Greenhill Rd',
#   'Boarding_sum': 0.08314319739538965,
#   'Boarding_count': 0.03901587096031541,
#   'Boarding_max': 0.08932117733062975},
#  {'StopName': '14 Harris Rd',
#   'Boarding_sum': 0.02038270276824903,
#   'Boarding_count': 0.003933634757073557,
#   'Boarding_max': 0.08994124800891823},
#  {'StopName': '14 Harrison Rd',
#   'Boarding_sum': 0.013309309505192591,
#   'Boarding_count': 0.002117464780521624,
#   'Boarding_max': 0.025190796555175626},
#  {'StopName': '14 Hartley Rd',
#   'Boarding_sum': 0.09247989551933108,
#   'Boarding_count': 0.001769653592183196,
#   'Boarding_max': 0.44510537163172004},
#  {'StopName': '14 Hawker St',
#   'Boarding_sum': 0.0034095249954117397,
#   'Boarding_count': -0.0007297634004074999,
#   'Boarding_max': 0.045476010723776994},
#  {'StopName': '14 Henley Beach Rd',
#   'Boarding_sum': 0.01479355382642137,
#   'Boarding_count': 0.0012137376946528956,
#   'Boarding_max': 0.07330033803086042},
#  {'StopName': '14 Kensington Rd',
#   'Boarding_sum': 0.029187252475369754,
#   'Boarding_count': 0.011434443601346518,
#   'Boarding_max': 0.0687542395875729},
#  {'StopName': '14 Magill Rd',
#   'Boarding_sum': 0.0073150025120419385,
#   'Boarding_count': 0.0017404758855310524,
#   'Boarding_max': 0.023981309638774376},
#  {'StopName': '14 Main North Rd',
#   'Boarding_sum': 0.01430922065068544,
#   'Boarding_count': -0.002100248420115095,
#   'Boarding_max': 0.07731290921592537},
#  {'StopName': '14 Marion Rd',
#   'Boarding_sum': 0.012113470616583997,
#   'Boarding_count': -0.00047335368239589227,
#   'Boarding_max': 0.0765474560430472},
#  {'StopName': '14 Mooringe Av',
#   'Boarding_sum': 0.03798307887685142,
#   'Boarding_count': 0.010168031730820109,
#   'Boarding_max': 0.10560043623769112},
#  {'StopName': '14 North East Rd',
#   'Boarding_sum': 0.022425881623010086,
#   'Boarding_count': 0.012475996112454353,
#   'Boarding_max': 0.07400410803188581},
#  {'StopName': '14 Payneham Rd',
#   'Boarding_sum': 0.011715128744861494,
#   'Boarding_count': 0.0018056640246200148,
#   'Boarding_max': 0.04623992837020611},
#  {'StopName': '14 Philip Av',
#   'Boarding_sum': 0.04070193177376645,
#   'Boarding_count': 0.007957985674435977,
#   'Boarding_max': 0.06617274934483396},
#  {'StopName': '14 Port Rd',
#   'Boarding_sum': 0.010291208716651826,
#   'Boarding_count': -0.0007614957005498844,
#   'Boarding_max': 0.07248462497000509},
#  {'StopName': '14 Prospect Rd',
#   'Boarding_sum': 0.014847126287090628,
#   'Boarding_count': 0.00181126707167425,
#   'Boarding_max': 0.07266482897617384},
#  {'StopName': '14 Rio Vista Av',
#   'Boarding_sum': 0.05329599726378117,
#   'Boarding_count': 0.015547658327159698,
#   'Boarding_max': 0.22860871647383033},
#  {'StopName': '14 Shelley St',
#   'Boarding_sum': 0.019322839471782444,
#   'Boarding_count': 0.0060072174248276475,
#   'Boarding_max': 0.0720117177372902},
#  {'StopName': '14 South Rd',
#   'Boarding_sum': 0.01650415718270517,
#   'Boarding_count': 0.010752340586261686,
#   'Boarding_max': 0.18749198332531666},
#  {'StopName': '14 South Tce',
#   'Boarding_sum': 0.04708606199637006,
#   'Boarding_count': 0.029675285613872598,
#   'Boarding_max': 0.06938632355299025},
#  {'StopName': '14 Stonehouse Av',
#   'Boarding_sum': 0.012625322708427455,
#   'Boarding_count': 0.0012632336454792518,
#   'Boarding_max': 0.12360000578766046},
#  {'StopName': '14 Sussex Tce',
#   'Boarding_sum': 0.008013113696166538,
#   'Boarding_count': 0.0018808064333330117,
#   'Boarding_max': 0.05535078775819518},
#  {'StopName': '14 Tapleys Hill Rd',
#   'Boarding_sum': 0.03110022397120889,
#   'Boarding_count': 0.01291381280062507,
#   'Boarding_max': 0.059588610977499866},
#  {'StopName': '14 The Parade',
#   'Boarding_sum': 0.032686362598851215,
#   'Boarding_count': 0.0032445350898600853,
#   'Boarding_max': 0.11155229060015116},
#  {'StopName': '14 Towers Tce',
#   'Boarding_sum': 0.018198074683645083,
#   'Boarding_count': 0.0074299810403311425,
#   'Boarding_max': 0.046498055910250614},
#  {'StopName': '14 Winston Av',
#   'Boarding_sum': 0.016904946295745623,
#   'Boarding_count': 0.0032267359689892995,
#   'Boarding_max': 0.04281697595681083},
#  {'StopName': '141 SELLICKS BEACH Rd',
#   'Boarding_sum': 0.15806492283144244,
#   'Boarding_count': 0.08589897756564423,
#   'Boarding_max': 0.17870031203364536},
#  {'StopName': '142 Murray St',
#   'Boarding_sum': 0.034505579999223344,
#   'Boarding_count': 0.0023035666900419163,
#   'Boarding_max': 0.06255801811357369},
#  {'StopName': '143 Murray St',
#   'Boarding_sum': 0.10188728829960138,
#   'Boarding_count': 0.0744993536703203,
#   'Boarding_max': 0.21290908746105877},
#  {'StopName': '143 Portrush Rd',
#   'Boarding_sum': 0.0935296643005512,
#   'Boarding_count': 0.028521388956660322,
#   'Boarding_max': 0.164694256360923},
#  {'StopName': '143 The Esplanade',
#   'Boarding_sum': 0.35008937077650526,
#   'Boarding_count': 0.2439854898188232,
#   'Boarding_max': 0.18364197530864199},
#  {'StopName': '144 Adelaide Rd',
#   'Boarding_sum': 0.25477326171770626,
#   'Boarding_count': 0.1756740687296243,
#   'Boarding_max': 0.13487654320987652},
#  {'StopName': '144 Portrush Rd',
#   'Boarding_sum': 0.05334331617417175,
#   'Boarding_count': 0.020471392851796562,
#   'Boarding_max': 0.10311815242370798},
#  {'StopName': '145 Adelaide Rd',
#   'Boarding_sum': 0.10790052913312362,
#   'Boarding_count': 0.0956035219924109,
#   'Boarding_max': 0.16945179306290417},
#  {'StopName': '145 Portrush Rd',
#   'Boarding_sum': 0.04657301357797073,
#   'Boarding_count': 0.010356416043143237,
#   'Boarding_max': 0.17872524066460901},
#  {'StopName': '145 The Esplanade',
#   'Boarding_sum': 0.2324514991181658,
#   'Boarding_count': 0.14043209876543206,
#   'Boarding_max': 0.1672839506172839},
#  {'StopName': '146 Gulfview Rd',
#   'Boarding_sum': 0.07548731922558233,
#   'Boarding_count': 0.04920835878438218,
#   'Boarding_max': 0.1997098066542511},
#  {'StopName': '146 Portrush Rd',
#   'Boarding_sum': 1.6032986069366784,
#   'Boarding_count': 0.08918808945321482,
#   'Boarding_max': 1.931535629313942},
#  {'StopName': '147 Portrush Rd',
#   'Boarding_sum': 0.27149043828429903,
#   'Boarding_count': 0.03717129325683665,
#   'Boarding_max': 0.5863617572230692},
#  {'StopName': '149 Portrush Rd',
#   'Boarding_sum': 0.5487897193099505,
#   'Boarding_count': 0.09548550484505579,
#   'Boarding_max': 0.8616427944398415},
#  {'StopName': '14A Anzac Hwy',
#   'Boarding_sum': 0.00842144334595698,
#   'Boarding_count': 0.0011438384826475906,
#   'Boarding_max': 0.040823843968801427},
#  {'StopName': '14A Edward St',
#   'Boarding_sum': 0.05553850576854386,
#   'Boarding_count': 0.015216983991228082,
#   'Boarding_max': 0.25293694086048746},
#  {'StopName': '14A Greenhill Rd',
#   'Boarding_sum': 0.21540883383612297,
#   'Boarding_count': 0.18866956089178316,
#   'Boarding_max': 0.07868433007321896},
#  {'StopName': '14A Ilford St',
#   'Boarding_sum': 0.016226712846118537,
#   'Boarding_count': 0.008504580965338956,
#   'Boarding_max': 0.037196205210911104},
#  {'StopName': '14A Pym St',
#   'Boarding_sum': 0.00037956957229952197,
#   'Boarding_count': 0.0018368651530315835,
#   'Boarding_max': 0.0447407916418509},
#  {'StopName': '14A Stonehouse Av',
#   'Boarding_sum': 0.033635792150236835,
#   'Boarding_count': 0.00042026433747962595,
#   'Boarding_max': 0.18094852141585727},
#  {'StopName': '14A Towers Tce',
#   'Boarding_sum': 0.019411029811042844,
#   'Boarding_count': 0.007756571506632178,
#   'Boarding_max': 0.08026745253052442},
#  {'StopName': '14A West Beach Rd',
#   'Boarding_sum': 0.09813967863341351,
#   'Boarding_count': 0.056590128519953056,
#   'Boarding_max': 0.32654320987654323},
#  {'StopName': '14B Edward St',
#   'Boarding_sum': 0.10612935340861501,
#   'Boarding_count': 0.048856721770397155,
#   'Boarding_max': 0.22536078846308366},
#  {'StopName': '14B West Beach Rd',
#   'Boarding_sum': 0.06397871041387536,
#   'Boarding_count': 0.038344352847633774,
#   'Boarding_max': 0.2901594584677772},
#  {'StopName': '14C Edward St',
#   'Boarding_sum': 0.11175974316678497,
#   'Boarding_count': 0.019884687983851762,
#   'Boarding_max': 0.3631072350406487},
#  {'StopName': '14C Harbour Town',
#   'Boarding_sum': 0.03616340322577209,
#   'Boarding_count': 0.01738674916585616,
#   'Boarding_max': 0.07805710618448988},
#  {'StopName': '14D Edward St',
#   'Boarding_sum': 0.09245269141737573,
#   'Boarding_count': 0.021833482114340472,
#   'Boarding_max': 0.3706511229385197},
#  {'StopName': '14E Edward St',
#   'Boarding_sum': 0.3196503084507554,
#   'Boarding_count': 0.018316124754388468,
# ...
#  {'StopName': '25 Blackburn Av',
#   'Boarding_sum': 0.05523198971344393,
#   'Boarding_count': 0.05441086482182937,
#   'Boarding_max': 0.11908436213991767},
#  {'StopName': '25 Bradley Gr',
#   'Boarding_sum': 0.04521915215507263,
#   'Boarding_count': 0.0165959374625752,
#   'Boarding_max': 0.11963550852439743},
#  {'StopName': '25 Brighton Rd',
#   'Boarding_sum': 0.023193460268507545,
#   'Boarding_count': 0.002640119117634012,
#   'Boarding_max': 0.16198567362513358},
#  {'StopName': '25 Darley Rd',
#   'Boarding_sum': 0.01928304990506912,
#   'Boarding_count': 0.005728000010583041,
#   'Boarding_max': 0.34155931312736354},
#  {'StopName': '25 Diagonal Rd',
#   'Boarding_sum': 0.062386112447604065,
#   'Boarding_count': 0.01713508693983248,
#   'Boarding_max': 0.34603717768106285},
#  {'StopName': '25 Finniss St',
#   'Boarding_sum': 0.013190883025766745,
#   'Boarding_count': 0.008623776272778836,
#   'Boarding_max': 0.0682262681037191},
#  {'StopName': '25 Fosters Rd',
#   'Boarding_sum': 0.02787404872439967,
#   'Boarding_count': 0.01860827095256584,
#   'Boarding_max': 0.05428990785695173},
#  {'StopName': '25 Gorge Rd',
#   'Boarding_sum': 0.10688992498450972,
#   'Boarding_count': 0.018707468488537327,
#   'Boarding_max': 0.5670906116824066},
#  {'StopName': '25 Grand Junction Rd',
#   'Boarding_sum': 0.05547728457768982,
#   'Boarding_count': 0.024364066095768983,
#   'Boarding_max': 0.07006473058919817},
#  {'StopName': '25 Grange Rd',
#   'Boarding_sum': 0.011837024878701037,
#   'Boarding_count': 0.0025994279317731604,
#   'Boarding_max': 0.06649113429729184},
#  {'StopName': '25 Greenhill Rd',
#   'Boarding_sum': 0.09031038726961015,
#   'Boarding_count': 0.02778980278980279,
#   'Boarding_max': 0.056532729831376756},
#  {'StopName': '25 Hampstead Rd',
#   'Boarding_sum': 0.0037057555116457998,
#   'Boarding_count': 0.0007499463264821904,
#   'Boarding_max': 0.041375918820200405},
#  {'StopName': '25 Hanson Rd',
#   'Boarding_sum': 0.020891836314013295,
#   'Boarding_count': 0.0057927498723564196,
#   'Boarding_max': 0.06182104327529162},
#  {'StopName': '25 Henley Beach Rd',
#   'Boarding_sum': 0.015879848963865982,
#   'Boarding_count': -0.00129143946259527,
#   'Boarding_max': 0.23840922880096357},
#  {'StopName': '25 Koonga Av',
#   'Boarding_sum': 0.010953443364425046,
#   'Boarding_count': 0.0019838080076476834,
#   'Boarding_max': 0.0648713631925503},
#  {'StopName': '25 Liberty Av',
#   'Boarding_sum': 0.017526983002416677,
#   'Boarding_count': 0.004257921675181923,
#   'Boarding_max': 0.053106422699215956},
#  {'StopName': '25 Liberty Gr',
#   'Boarding_sum': 0.2512670547749506,
#   'Boarding_count': 0.2081284456284456,
#   'Boarding_max': 0.2443148415370638},
#  {'StopName': '25 Lower North East Rd',
#   'Boarding_sum': 0.011294595327598288,
#   'Boarding_count': 0.0007518049785953734,
#   'Boarding_max': 0.10379502787004917},
#  {'StopName': '25 Main North Rd',
#   'Boarding_sum': 0.0056923957910202,
#   'Boarding_count': -0.0007286780853709378,
#   'Boarding_max': 0.10003146428389675},
#  {'StopName': '25 Main St',
#   'Boarding_sum': 0.05825142832667596,
#   'Boarding_count': 0.018005218185910825,
#   'Boarding_max': 0.3240045461631414},
#  {'StopName': '25 Montacute Rd',
#   'Boarding_sum': 0.00681220653172084,
#   'Boarding_count': 0.0039092830669467055,
#   'Boarding_max': 0.04235080004891091},
#  {'StopName': '25 Morialta Rd',
#   'Boarding_sum': 0.026934559605264898,
#   'Boarding_count': 0.008774223715474795,
#   'Boarding_max': 0.28697269750418647},
#  {'StopName': '25 Morphett Rd',
#   'Boarding_sum': 0.031794313151988766,
#   'Boarding_count': 0.030234491281455174,
#   'Boarding_max': 0.10732074902826537},
#  {'StopName': '25 Moseley St',
#   'Boarding_sum': 0.02503534460418749,
#   'Boarding_count': 0.013352623873075157,
#   'Boarding_max': 0.06477846771964418},
#  {'StopName': '25 North East Rd',
#   'Boarding_sum': 0.012417117940575742,
#   'Boarding_count': 0.0015036455521667093,
#   'Boarding_max': 0.064927200861116},
#  {'StopName': '25 North St',
#   'Boarding_sum': 0.09345593908486975,
#   'Boarding_count': 0.039101288237406454,
#   'Boarding_max': 0.10202933843284721},
#  {'StopName': '25 Pellew St',
#   'Boarding_sum': 0.018841936637174685,
#   'Boarding_count': 0.008707107631128051,
#   'Boarding_max': 0.04816428393644557},
#  {'StopName': '25 Port Rd',
#   'Boarding_sum': 0.029549991707537752,
#   'Boarding_count': 0.020643343299667424,
#   'Boarding_max': 0.06818783068783069},
#  {'StopName': '25 Seaview Rd',
#   'Boarding_sum': 0.06793543659965541,
#   'Boarding_count': 0.07590116361616189,
#   'Boarding_max': 0.09501763668430332},
#  {'StopName': '25 Shepherds Hill Rd',
#   'Boarding_sum': 0.047877877766393594,
#   'Boarding_count': 0.03258708067965053,
#   'Boarding_max': 0.16493997257886145},
#  {'StopName': '25 South Rd',
#   'Boarding_sum': 0.02319805740279381,
#   'Boarding_count': 0.014378566195300566,
#   'Boarding_max': 0.10523066926575698},
#  {'StopName': '25 Sycamore Tce',
#   'Boarding_sum': 0.10407134561910872,
#   'Boarding_count': 0.04444585589021433,
#   'Boarding_max': 0.1678837940684346},
#  {'StopName': '25 Torrens Rd',
#   'Boarding_sum': 0.031126193059763694,
#   'Boarding_count': 0.008104910792963212,
#   'Boarding_max': 0.11210523016078572},
#  {'StopName': '25 Trimmer Pde',
#   'Boarding_sum': 0.0030973155876248127,
#   'Boarding_count': 0.00010995112200028344,
#   'Boarding_max': 0.04703382981031762},
#  {'StopName': '25 Valetta Rd',
#   'Boarding_sum': 0.003789475344666469,
#   'Boarding_count': -0.0013114208015520957,
#   'Boarding_max': 0.023384504271013854},
#  {'StopName': '25 Vine St',
#   'Boarding_sum': 0.036690775145338965,
#   'Boarding_count': 0.011505071547256484,
#   'Boarding_max': 0.3320005795151545},
#  {'StopName': '25A Bells Rd',
#   'Boarding_sum': 0.019604932958026972,
#   'Boarding_count': 0.0167043488636084,
#   'Boarding_max': 0.06619126758015643},
#  {'StopName': '25A Darley Rd',
#   'Boarding_sum': 0.04861144315029445,
#   'Boarding_count': 0.01888394636089655,
#   'Boarding_max': 0.1971635975828486},
#  {'StopName': '25A Diagonal Rd',
#   'Boarding_sum': 0.2916818034637092,
#   'Boarding_count': 0.24479512257290034,
#   'Boarding_max': 0.10401234567901234},
#  {'StopName': '25A Fosters Rd',
#   'Boarding_sum': 0.017576689193542955,
#   'Boarding_count': 0.007755746588770096,
#   'Boarding_max': 0.03708819418013645},
#  {'StopName': '25A Grand Junction Rd',
#   'Boarding_sum': 0.16396723560237325,
#   'Boarding_count': 0.016252261221928348,
#   'Boarding_max': 0.3812252209349723},
#  {'StopName': '25A Greenhill Rd',
#   'Boarding_sum': 0.17113612398478104,
#   'Boarding_count': 0.05325209769654214,
#   'Boarding_max': 0.3037089604201038},
#  {'StopName': '25A Liberty Gr',
#   'Boarding_sum': 0.0054105235572437125,
#   'Boarding_count': 0.0010426900076775175,
#   'Boarding_max': 0.05368684363713954},
#  {'StopName': '25A Main South Rd',
#   'Boarding_sum': 0.017536287959945364,
#   'Boarding_count': 0.009735361983644933,
#   'Boarding_max': 0.040194938806049914},
#  {'StopName': '25A Morialta Rd',
#   'Boarding_sum': 0.007630817327794994,
#   'Boarding_count': 0.002607573767959481,
#   'Boarding_max': 0.07737889682334129},
#  {'StopName': '25A Morialta Road',
#   'Boarding_sum': 0.10973798802121741,
#   'Boarding_count': 0.1128778114889226,
#   'Boarding_max': 0.12169312169312169},
#  {'StopName': '25A Tapleys Hill Rd',
#   'Boarding_sum': 0.258922685056156,
#   'Boarding_count': 0.11476337448559672,
#   'Boarding_max': 0.24012345679012342},
#  {'StopName': '25B Bells Rd',
#   'Boarding_sum': 0.021582867129945962,
#   'Boarding_count': 0.03195002047988416,
#   'Boarding_max': 0.0961099086099086},
#  {'StopName': '25B Diagonal Rd',
#   'Boarding_sum': 0.018859204594655628,
#   'Boarding_count': 0.016919938126536575,
#   'Boarding_max': 0.049948559670781906},
#  {'StopName': '25B Fosters Rd',
#   'Boarding_sum': 0.016431969477415778,
#   'Boarding_count': 0.010825432328452303,
#   'Boarding_max': 0.06706923304616837},
#  {'StopName': '25B Main South Rd',
#   'Boarding_sum': 0.004944544999037467,
#   'Boarding_count': 0.004889254728224394,
#   'Boarding_max': 0.19084189231248055},
#  {'StopName': '25B Tapleys Hill Rd',
#   'Boarding_sum': 0.07784294248846448,
#   'Boarding_count': 0.07824772963661852,
#   'Boarding_max': 0.09982119671662153},
#  {'StopName': '25C Bells Rd',
#   'Boarding_sum': 0.019727549849581166,
#   'Boarding_count': 0.020406599272001502,
#   'Boarding_max': 0.0734243637021415},
#  {'StopName': '25C The Strand',
#   'Boarding_sum': 0.08269140087860567,
#   'Boarding_count': 0.029556400389733735,
#   'Boarding_max': 0.1576812429804084},
#  {'StopName': '25P Pier St',
#   'Boarding_sum': 0.06464565511627803,
#   'Boarding_count': 0.03186795863027223,
#   'Boarding_max': 0.18658764075430742},
#  {'StopName': '26 Bradley Gr',
#   'Boarding_sum': 0.0013206605997714016,
#   'Boarding_count': -0.0020073108413572707,
#   'Boarding_max': 0.046241155963378175},
#  {'StopName': '26 Brighton Rd',
#   'Boarding_sum': 0.03222733710599736,
#   'Boarding_count': 0.018895837197682907,
#   'Boarding_max': 0.0905790711346267},
#  {'StopName': '26 Diagonal Rd',
#   'Boarding_sum': 0.00916306008176494,
#   'Boarding_count': 0.0044146234058849,
#   'Boarding_max': 0.12187832743388298},
#  {'StopName': '26 Finniss St',
#   'Boarding_sum': 0.02261670197477546,
#   'Boarding_count': 0.01106764320976157,
#   'Boarding_max': 0.06449204088092977},
#  {'StopName': '26 Folland Av',
#   'Boarding_sum': 0.07009702426840367,
#   'Boarding_count': 0.02269456750070729,
#   'Boarding_max': 0.6599294325762921},
#  {'StopName': '26 Gorge Rd',
#   'Boarding_sum': 0.04940436518749473,
#   'Boarding_count': 0.0005348165297658071,
#   'Boarding_max': 0.32238346587111394},
#  {'StopName': '26 Grand Junction Rd',
#   'Boarding_sum': 0.05703094038171606,
#   'Boarding_count': 0.01959628012971575,
#   'Boarding_max': 0.08366249950861247},
#  {'StopName': '26 Grange Rd',
#   'Boarding_sum': 0.015407660328737124,
#   'Boarding_count': 0.004096454106438463,
#   'Boarding_max': 0.03996557333975635},
#  {'StopName': '26 Hampstead Rd',
#   'Boarding_sum': 0.011904972230258661,
#   'Boarding_count': -0.0002784702345990211,
#   'Boarding_max': 0.04533953424462934},
#  {'StopName': '26 Hanson Rd',
#   'Boarding_sum': 0.0065548630064928915,
#   'Boarding_count': 0.00093561201005855,
#   'Boarding_max': 0.059211136221370135},
#  {'StopName': '26 Koonga Av',
#   'Boarding_sum': 0.03602274758467936,
#   'Boarding_count': 0.005779916781752085,
#   'Boarding_max': 0.09849845485969615},
#  {'StopName': '26 Lower North East Rd',
#   'Boarding_sum': 0.14026702842062325,
#   'Boarding_count': 0.12294135905247018,
#   'Boarding_max': 0.17993827160493828},
#  {'StopName': '26 Magill Rd',
#   'Boarding_sum': 0.030191708724829,
#   'Boarding_count': 0.000697258238537742,
#   'Boarding_max': 0.4384850045060415},
#  {'StopName': '26 Main North Rd',
#   'Boarding_sum': 0.01853839351663051,
#   'Boarding_count': 0.008371966798825299,
#   'Boarding_max': 0.0844658977483389},
#  {'StopName': '26 Main Rd',
#   'Boarding_sum': 0.589326214171318,
#   'Boarding_count': 0.09090975896531452,
#   'Boarding_max': 0.5313528200659712},
#  {'StopName': '26 Main South Rd',
#   'Boarding_sum': 0.016465716915352886,
#   'Boarding_count': 0.0030293512247923527,
#   'Boarding_max': 0.09568892689186999},
#  {'StopName': '26 Marlborough St',
#   'Boarding_sum': 0.038314864825964835,
#   'Boarding_count': 0.01278174652508708,
#   'Boarding_max': 0.1057403562305523},
#  {'StopName': '26 Montacute Rd',
#   'Boarding_sum': 0.0075087111114492235,
#   'Boarding_count': 0.00022519802361425304,
#   'Boarding_max': 0.07416410950485425},
#  {'StopName': '26 Morialta Rd',
#   'Boarding_sum': 0.02966543496008924,
#   'Boarding_count': 0.009043862959940337,
#   'Boarding_max': 0.071203528235274},
#  {'StopName': '26 Morphett Rd',
#   'Boarding_sum': 0.015192864903713289,
#   'Boarding_count': 0.004547348566721555,
#   'Boarding_max': 0.06400671768318826},
#  {'StopName': '26 North East Rd',
#   'Boarding_sum': 0.01785323770472069,
#   'Boarding_count': 0.0023400099891281406,
#   'Boarding_max': 0.061921736192611605},
#  {'StopName': '26 North St',
#   'Boarding_sum': 0.11250381701497138,
#   'Boarding_count': 0.023835514026507285,
#   'Boarding_max': 0.5797209969838074},
#  {'StopName': '26 Pitman Rd',
#   'Boarding_sum': 0.03759707664607706,
#   'Boarding_count': 0.03484237728665221,
#   'Boarding_max': 0.0628747795414462},
#  {'StopName': '26 Port Rd',
#   'Boarding_sum': 0.04342448142395069,
#   'Boarding_count': 0.016854137973822444,
#   'Boarding_max': 0.08923393841694499},
#  {'StopName': '26 Seaview Rd',
#   'Boarding_sum': 0.019727777384480994,
#   'Boarding_count': 0.0018472300357850026,
#   'Boarding_max': 0.07805936863845966},
#  {'StopName': '26 Shepherds Hill Rd',
#   'Boarding_sum': 0.01486634324638034,
#   'Boarding_count': 0.0019367047653595381,
#   'Boarding_max': 0.07691536619555196},
#  {'StopName': '26 Shepherds La',
#   'Boarding_sum': 0.09316446118717929,
#   'Boarding_count': 0.028310746067327287,
#   'Boarding_max': 0.32791603581813333},
#  {'StopName': '26 Sturt Rd',
#   'Boarding_sum': 0.06125618487516497,
#   'Boarding_count': 0.015685566802363778,
#   'Boarding_max': 0.3727810862848631},
#  {'StopName': '26 Summit Rd Mount Lofty Summi',
#   'Boarding_sum': 0.22041289858363622,
#   'Boarding_count': 0.07884332745443856,
#   'Boarding_max': 0.31977467725231745},
#  {'StopName': '26 Tapleys Hill Rd',
#   'Boarding_sum': 0.05654161122280305,
#   'Boarding_count': 0.03760741195381718,
#   'Boarding_max': 0.07880658436213991},
#  {'StopName': '26 Tarlton St',
#   'Boarding_sum': 0.03161515033573837,
#   'Boarding_count': 0.010838078771925722,
#   'Boarding_max': 0.1539261848020878},
#  {'StopName': '26 Torrens Rd',
#   'Boarding_sum': 0.01880166670169032,
#   'Boarding_count': 0.004127319525886387,
#   'Boarding_max': 0.21468754632296658},
#  {'StopName': '26 Township Rd',
#   'Boarding_sum': 0.006275038868512036,
#   'Boarding_count': 0.0007772819134097718,
#   'Boarding_max': 0.025516789497629103},
#  {'StopName': '26 Trafford St',
#   'Boarding_sum': 0.008472003450264625,
#   'Boarding_count': 0.0019527877491944813,
#   'Boarding_max': 0.06066950430566478},
#  {'StopName': '26 Trimmer Pde',
#   'Boarding_sum': 0.005384605856038944,
#   'Boarding_count': 0.0005361830414536725,
#   'Boarding_max': 0.04703001967836848},
#  {'StopName': '26A  Navigator Dr',
#   'Boarding_sum': 0.018870633121845073,
#   'Boarding_count': 0.008786019718322583,
#   'Boarding_max': 0.0713702648703063},
#  {'StopName': '26A Bradley Gr',
#   'Boarding_sum': 0.02337426058724912,
#   'Boarding_count': 0.0217763104070835,
#   'Boarding_max': 0.09371425899203677},
#  {'StopName': '26A Diagonal Rd',
#   'Boarding_sum': 0.011166548435996874,
#   'Boarding_count': -0.00047812159340092315,
#   'Boarding_max': 0.10679978306612295},
#  {'StopName': '26A Gorge Rd',
#   'Boarding_sum': 0.01851512330385708,
#   'Boarding_count': 0.008767752416890342,
#   'Boarding_max': 0.049426275097069726},
#  {'StopName': '26A Grange Rd',
#   'Boarding_sum': 0.005652816570445355,
#   'Boarding_count': 0.0037715740827857264,
#   'Boarding_max': 0.03367201365567379},
#  {'StopName': '26A Lower North East Rd',
#   'Boarding_sum': 0.06355131389518422,
#   'Boarding_count': 0.004029886128424204,
#   'Boarding_max': 0.20673824215929096},
#  {'StopName': '26A Trafford St',
#   'Boarding_sum': 0.010326429340240794,
#   'Boarding_count': 0.0011067741332183804,
#   'Boarding_max': 0.04695236022724961},
#  {'StopName': '26A University Dr',
#   'Boarding_sum': 0.0868067302657554,
#   'Boarding_count': 0.011466001864249729,
#   'Boarding_max': 0.2285798635837448},
#  {'StopName': '26B Navigator Dr',
#   'Boarding_sum': 0.08206191214300217,
#   'Boarding_count': 0.023948489769707718,
#   'Boarding_max': 0.2661746899503346},
#  {'StopName': '26B University Dr',
#   'Boarding_sum': 0.15127010362330362,
#   'Boarding_count': 0.015503266259820583,
#   'Boarding_max': 0.23731567005939866},
#  {'StopName': '26C The Promenade',
#   'Boarding_sum': 0.02610042647185637,
#   'Boarding_count': 0.00533188592670419,
#   'Boarding_max': 0.05567228266751258},
#  {'StopName': '26D University Dr',
#   'Boarding_sum': 0.3010640177218673,
#   'Boarding_count': 0.06598168803521248,
#   'Boarding_max': 0.42100805319564577},
#  {'StopName': '27 Bradley Gr',
#   'Boarding_sum': 0.02810890800993522,
#   'Boarding_count': 0.011618024419287951,
#   'Boarding_max': 0.06379588093960074},
#  {'StopName': '27 Brighton Rd',
#   'Boarding_sum': 0.01286052902721846,
#   'Boarding_count': 0.008204307557431668,
#   'Boarding_max': 0.04322027077781554},
#  ...]

# %%
pct_chng.head()
# Out:
#          StopName  Boarding_sum  Boarding_count  Boarding_max
# 0     1 Anzac Hwy      0.020180        0.004317      0.218099
# 1    1 Bartels Rd      0.281967        0.195600      0.108385
# 2    1 Botanic Rd      0.008744        0.002424      0.143144
# 3      1 Frome Rd      0.028297        0.004165      0.059076
# 4  1 Fullarton Rd      0.331698        0.195885      0.220844

# %%
pct_chng.shape
# Out:
# (3249, 4)

# %%
pct_chng['Boarding_sum'].nlargest(5)
# Out:
# 3110    9.610182
# 2134    4.454329
# 214     2.678186
# 1538    2.153380
# 1290    1.913630
# Name: Boarding_sum, dtype: float64

# %%
pct_chng['Boarding_sum'].nsmallest(5)
# Out:
# 1672   -0.011979
# 250    -0.011317
# 3115   -0.010744
# 1840   -0.009904
# 1113   -0.008562
# Name: Boarding_sum, dtype: float64

# %%
pct_chng[pct_chng['Boarding_sum']<0].shape
# Out:
# (27, 4)

# %%
pct_chng.iloc[[3110,2134,214,1538,1290]]
# Out:
#               StopName  Boarding_sum  Boarding_count  Boarding_max
# 3110        W Grote St      9.610182        2.183068      0.301880
# 2134     52 Taylors Rd      4.454329        0.250926      5.611376
# 214         13 Tutt Av      2.678186        0.153529      2.273410
# 1538   37A Longwood Rd      2.153380        0.115724      4.608867
# 1290  32A Frederick Rd      1.913630        0.148205      2.500424

# %%
out_geo=pd.read_csv("output_geo.csv")

# %%
out_geo.shape
# Out:
# (4165, 10)

# %%
from math import sin, cos, sqrt, atan2, radians
def calc_dist(lat1,lon1):
    ## approximate radius of earth in km
    R = 6373.0
    dlon = radians(138.604801) - radians(lon1)
    dlat = radians(-34.921247) - radians(lat1)
    a = sin(dlat / 2)**2 + cos(radians(lat1)) * cos(radians(-34.921247)) * sin(dlon / 2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))
    return R * c

# %%
out_geo['dist_from_centre'] = out_geo[['latitude','longitude']].apply(lambda x: calc_dist(*x), axis=1)

# %%
out_geo.head()
# Out:
#            accuracy                                  formatted_address  \
# 0           ROOFTOP   181 Cross Rd, Westbourne Park SA 5041, Australia
# 1           ROOFTOP   177 Cross Rd, Westbourne Park SA 5041, Australia
# 2           ROOFTOP   175 Cross Rd, Westbourne Park SA 5041, Australia
# 3  GEOMETRIC_CENTER  Zone A Arndale Interchange - South side, Kilke...
# 4           ROOFTOP           178 Cross Rd, Malvern SA 5061, Australia
#
#                google_place_id                input_string   latitude  \
# 0  ChIJKT7I9rbPsGoRVHMHkIy-Oyk                181 Cross Rd -34.966656
# 1  ChIJ-VFZ87bPsGoRyfVgC5qbPpE                177 Cross Rd -34.966607
# 2  ChIJIztlirbPsGoR38KRk76kPFI                175 Cross Rd -34.966758
# 3  ChIJn0C1hCPGsGoRIWvCdhF1RIg  Zone A Arndale Interchange -34.875160
# 4  ChIJycNiylvOsGoRdhfq9GKnpq0                178 Cross Rd -34.964960
#
#     longitude  number_of_results postcode status  \
# 0  138.592148                  1     5041     OK
# 1  138.592301                  1     5041     OK
# 2  138.592715                  1     5041     OK
# 3  138.551628                  1     5009     OK
# 4  138.611477                  1     5061     OK
#
#                                                 type  dist_from_centre
# 0                                     street_address          5.180961
# 1                                     street_address          5.172525
# 2                                     street_address          5.180709
# 3  bus_station,establishment,point_of_interest,tr...          7.057549
# 4                                     street_address          4.900099

# %%
##Fill the missing values with mode
out_geo['type'].fillna('street_address',inplace=True)
out_geo['type'] = out_geo['type'].apply(lambda x: str(x).split(',')[-1])

# %%
out_geo.isna().sum()
# Out:
# accuracy               4
# formatted_address      4
# google_place_id        4
# input_string           0
# latitude               0
# longitude              0
# number_of_results      0
# postcode             199
# status                 0
# type                   0
# dist_from_centre       0
# dtype: int64

# %%
out_geo['type'].unique()
# Out:
# array(['street_address', 'transit_station', 'premise', 'political',
#        'school', 'route', 'intersection', 'point_of_interest',
#        'subpremise', 'real_estate_agency', 'university', 'travel_agency',
#        'restaurant', 'supermarket', 'store', 'post_office'], dtype=object)

# %% [raw]
# '''Holidays--
# 2013-09-01,Father's Day
# 2013-10-07,Labour day
# 2013-12-25,Christmas day
# 2013-12-26,Proclamation Day
# 2014-01-01,New Year
# 2014-01-27,Australia Day
# 2014-03-10,March Public Holiday
# 2014-04-18,Good Friday
# 2014-04-19,Easter Saturday
# 2014-04-21,Easter Monday
# 2014-04-25,Anzac Day
# 2014-06-09,Queen's Birthday''

# %%
import datetime
def holiday_label (row):
    if row == datetime.date(2013, 9, 1) :
          return '1'
    if row == datetime.date(2013, 10, 6) :
          return '1'
    if row == datetime.date(2013, 12, 22) :
          return '2'
    if row == datetime.date(2013, 12, 29):
          return '1'
    if row  == datetime.date(2014, 1, 26):
          return '1'
    if row == datetime.date(2014, 3, 9):
          return '1'
    if row == datetime.date(2014, 4, 13) :
          return '2'
    if row == datetime.date(2014, 4, 20):
          return '2'
    if row == datetime.date(2014, 6, 8):
          return '1'
    return '0'

# %%
df['WeekBeginning'] = pd.to_datetime(df['WeekBeginning']).dt.date

# %%
df.head()
# Out:
#    TripID RouteID  StopID                    StopName WeekBeginning  \
# 0   23631     100   14156                181 Cross Rd    2013-06-30
# 1   23631     100   14144                177 Cross Rd    2013-06-30
# 2   23632     100   14132                175 Cross Rd    2013-06-30
# 3   23633     100   12266  Zone A Arndale Interchange    2013-06-30
# 4   23633     100   14147                178 Cross Rd    2013-06-30
#
#    NumberOfBoardings                                  formatted_address  \
# 0                  1   181 Cross Rd, Westbourne Park SA 5041, Australia
# 1                  1   177 Cross Rd, Westbourne Park SA 5041, Australia
# 2                  1   175 Cross Rd, Westbourne Park SA 5041, Australia
# 3                  2  Zone A Arndale Interchange - South side, Kilke...
# 4                  1           178 Cross Rd, Malvern SA 5061, Australia
#
#     latitude   longitude postcode             type  \
# 0 -34.966656  138.592148     5041   street_address
# 1 -34.966607  138.592301     5041   street_address
# 2 -34.966758  138.592715     5041   street_address
# 3 -34.875160  138.551628     5009  transit_station
# 4 -34.964960  138.611477     5061   street_address
#
#                                           route_desc  dist_from_centre  \
# 0  via Woodville Road, Holbrooks Road, Marion Roa...          5.180961
# 1  via Woodville Road, Holbrooks Road, Marion Roa...          5.172525
# 2  via Woodville Road, Holbrooks Road, Marion Roa...          5.180709
# 3  via Woodville Road, Holbrooks Road, Marion Roa...          7.057549
# 4  via Woodville Road, Holbrooks Road, Marion Roa...          4.900099
#
#    holiday_label
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0

# %%
df['holiday_label'] = df['WeekBeginning'].apply (lambda row: holiday_label(row))

# %%
df.head()
# Out:
#    TripID RouteID  StopID                    StopName WeekBeginning  \
# 0   23631     100   14156                181 Cross Rd    2013-06-30
# 1   23631     100   14144                177 Cross Rd    2013-06-30
# 2   23632     100   14132                175 Cross Rd    2013-06-30
# 3   23633     100   12266  Zone A Arndale Interchange    2013-06-30
# 4   23633     100   14147                178 Cross Rd    2013-06-30
#
#    NumberOfBoardings                                  formatted_address  \
# 0                  1   181 Cross Rd, Westbourne Park SA 5041, Australia
# 1                  1   177 Cross Rd, Westbourne Park SA 5041, Australia
# 2                  1   175 Cross Rd, Westbourne Park SA 5041, Australia
# 3                  2  Zone A Arndale Interchange - South side, Kilke...
# 4                  1           178 Cross Rd, Malvern SA 5061, Australia
#
#     latitude   longitude postcode             type  \
# 0 -34.966656  138.592148     5041   street_address
# 1 -34.966607  138.592301     5041   street_address
# 2 -34.966758  138.592715     5041   street_address
# 3 -34.875160  138.551628     5009  transit_station
# 4 -34.964960  138.611477     5061   street_address
#
#                                           route_desc  dist_from_centre  \
# 0  via Woodville Road, Holbrooks Road, Marion Roa...          5.180961
# 1  via Woodville Road, Holbrooks Road, Marion Roa...          5.172525
# 2  via Woodville Road, Holbrooks Road, Marion Roa...          5.180709
# 3  via Woodville Road, Holbrooks Road, Marion Roa...          7.057549
# 4  via Woodville Road, Holbrooks Road, Marion Roa...          4.900099
#
#   holiday_label
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0

# %% [markdown]
# ## Predictive Modelling

# %%
bb1 = pd.merge(bb, out_geo, how='left', left_on = 'StopName', right_on = 'input_string')

# %%
bb.shape
# Out:
# (175446, 7)

# %%
out_geo.shape
# Out:
# (4165, 11)

# %%
bb1.head()
# Out:
#       StopName WeekBeginning          type_x  NumberOfBoardings_sum  \
# 0  1 Anzac Hwy    2013-06-30  street_address                   1003
# 1  1 Anzac Hwy    2013-07-07  street_address                    783
# 2  1 Anzac Hwy    2013-07-14  street_address                    843
# 3  1 Anzac Hwy    2013-07-21  street_address                    710
# 4  1 Anzac Hwy    2013-07-28  street_address                    898
#
#    NumberOfBoardings_count  NumberOfBoardings_max  NumberOfBoardings_min  \
# 0                      378                     51                      1
# 1                      360                     28                      1
# 2                      343                     45                      1
# 3                      356                     28                      1
# 4                      379                     41                      1
#
#   accuracy                        formatted_address  \
# 0  ROOFTOP  1 Anzac Hwy, Keswick SA 5035, Australia
# 1  ROOFTOP  1 Anzac Hwy, Keswick SA 5035, Australia
# 2  ROOFTOP  1 Anzac Hwy, Keswick SA 5035, Australia
# 3  ROOFTOP  1 Anzac Hwy, Keswick SA 5035, Australia
# 4  ROOFTOP  1 Anzac Hwy, Keswick SA 5035, Australia
#
#                google_place_id input_string   latitude  longitude  \
# 0  ChIJx2AyjwvPsGoRvAINzhi9VmA  1 Anzac Hwy -34.942418  138.58183
# 1  ChIJx2AyjwvPsGoRvAINzhi9VmA  1 Anzac Hwy -34.942418  138.58183
# 2  ChIJx2AyjwvPsGoRvAINzhi9VmA  1 Anzac Hwy -34.942418  138.58183
# 3  ChIJx2AyjwvPsGoRvAINzhi9VmA  1 Anzac Hwy -34.942418  138.58183
# 4  ChIJx2AyjwvPsGoRvAINzhi9VmA  1 Anzac Hwy -34.942418  138.58183
#
#    number_of_results postcode status          type_y  dist_from_centre
# 0                  1     5035     OK  street_address          3.151684
# 1                  1     5035     OK  street_address          3.151684
# 2                  1     5035     OK  street_address          3.151684
# 3                  1     5035     OK  street_address          3.151684
# 4                  1     5035     OK  street_address          3.151684

# %%
bb1.shape
# Out:
# (175446, 18)

# %%
bb1['holiday_label'] = bb1['WeekBeginning'].apply (lambda row: holiday_label(row))

# %%
##Final 11 features have been used for the forecastng.
cols = ['StopName','WeekBeginning','type_x','NumberOfBoardings_sum','NumberOfBoardings_count','NumberOfBoardings_max','latitude','longitude','postcode','dist_from_centre','holiday_label']
bb1=bb1[cols]

# %%
bb1.head()
# Out:
#       StopName WeekBeginning          type_x  NumberOfBoardings_sum  \
# 0  1 Anzac Hwy    2013-06-30  street_address                   1003
# 1  1 Anzac Hwy    2013-07-07  street_address                    783
# 2  1 Anzac Hwy    2013-07-14  street_address                    843
# 3  1 Anzac Hwy    2013-07-21  street_address                    710
# 4  1 Anzac Hwy    2013-07-28  street_address                    898
#
#    NumberOfBoardings_count  NumberOfBoardings_max   latitude  longitude  \
# 0                      378                     51 -34.942418  138.58183
# 1                      360                     28 -34.942418  138.58183
# 2                      343                     45 -34.942418  138.58183
# 3                      356                     28 -34.942418  138.58183
# 4                      379                     41 -34.942418  138.58183
#
#   postcode  dist_from_centre holiday_label
# 0     5035          3.151684             0
# 1     5035          3.151684             0
# 2     5035          3.151684             0
# 3     5035          3.151684             0
# 4     5035          3.151684             0

# %%
bb1.shape
# Out:
# (175446, 11)

# %%
bb1.head()
# Out:
#       StopName WeekBeginning          type_x  NumberOfBoardings_sum  \
# 0  1 Anzac Hwy    2013-06-30  street_address                   1003
# 1  1 Anzac Hwy    2013-07-07  street_address                    783
# 2  1 Anzac Hwy    2013-07-14  street_address                    843
# 3  1 Anzac Hwy    2013-07-21  street_address                    710
# 4  1 Anzac Hwy    2013-07-28  street_address                    898
#
#    NumberOfBoardings_count  NumberOfBoardings_max   latitude  longitude  \
# 0                      378                     51 -34.942418  138.58183
# 1                      360                     28 -34.942418  138.58183
# 2                      343                     45 -34.942418  138.58183
# 3                      356                     28 -34.942418  138.58183
# 4                      379                     41 -34.942418  138.58183
#
#   postcode  dist_from_centre holiday_label
# 0     5035          3.151684             0
# 1     5035          3.151684             0
# 2     5035          3.151684             0
# 3     5035          3.151684             0
# 4     5035          3.151684             0

# %%
##Replace all Nan by Mode
for i in bb1.columns:
    bb1[i].fillna(bb1[i].mode()[0], inplace=True)
bb1[["postcode", "holiday_label"]] = bb1[["postcode", "holiday_label"]].apply(pd.to_numeric)

# %%
bb1.isna().sum()
# Out:
# StopName                   0
# WeekBeginning              0
# type_x                     0
# NumberOfBoardings_sum      0
# NumberOfBoardings_count    0
# NumberOfBoardings_max      0
# latitude                   0
# longitude                  0
# postcode                   0
# dist_from_centre           0
# holiday_label              0
# dtype: int64

# %%
bb1.WeekBeginning
# Out:
# 0         2013-06-30
# 1         2013-07-07
# 2         2013-07-14
# 3         2013-07-21
# 4         2013-07-28
#              ...
# 175441    2014-06-08
# 175442    2014-06-15
# 175443    2014-06-22
# 175444    2014-06-29
# 175445    2014-07-06
# Name: WeekBeginning, Length: 175446, dtype: object

# %%
bb1["WeekBeginning"] = bb1[["WeekBeginning"]].apply(pd.to_datetime)

# %%
train = bb1[bb1['WeekBeginning'] < datetime.strptime("2014-06-01","%Y-%m-%d")]
test = bb1[bb1['WeekBeginning'] >= datetime.strptime("2014-06-01","%Y-%m-%d")]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
train['WeekBeginning'] = le.fit_transform(train['WeekBeginning'])
test['WeekBeginning'] = le.fit_transform(test['WeekBeginning'])
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9864\3417846909.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['WeekBeginning'] = le.fit_transform(train['WeekBeginning'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9864\3417846909.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['WeekBeginning'] = le.fit_transform(test['WeekBeginning'])

# %%
train
# Out:
#                             StopName  WeekBeginning           type_x  \
# 0                        1 Anzac Hwy              0   street_address
# 1                        1 Anzac Hwy              1   street_address
# 2                        1 Anzac Hwy              2   street_address
# 3                        1 Anzac Hwy              3   street_address
# 4                        1 Anzac Hwy              4   street_address
# ...                              ...            ...              ...
# 175435  Zone I Salisbury Interchange             43  transit_station
# 175436  Zone I Salisbury Interchange             44  transit_station
# 175437  Zone I Salisbury Interchange             45  transit_station
# 175438  Zone I Salisbury Interchange             46  transit_station
# 175439  Zone I Salisbury Interchange             47  transit_station
#
#         NumberOfBoardings_sum  NumberOfBoardings_count  NumberOfBoardings_max  \
# 0                        1003                      378                     51
# 1                         783                      360                     28
# 2                         843                      343                     45
# 3                         710                      356                     28
# 4                         898                      379                     41
# ...                       ...                      ...                    ...
# 175435                    957                      101                     48
# 175436                   1054                      114                     59
# 175437                   1151                      119                     60
# 175438                   1040                      112                     57
# 175439                    939                      108                     51
#
#          latitude   longitude  postcode  dist_from_centre  holiday_label
# 0      -34.942418  138.581830      5035          3.151684              0
# 1      -34.942418  138.581830      5035          3.151684              0
# 2      -34.942418  138.581830      5035          3.151684              0
# 3      -34.942418  138.581830      5035          3.151684              0
# 4      -34.942418  138.581830      5035          3.151684              0
# ...           ...         ...       ...               ...            ...
# 175435 -34.763408  138.642747      5108         17.894924              0
# 175436 -34.763408  138.642747      5108         17.894924              0
# 175437 -34.763408  138.642747      5108         17.894924              0
# 175438 -34.763408  138.642747      5108         17.894924              0
# 175439 -34.763408  138.642747      5108         17.894924              0
#
# [155952 rows x 11 columns]

# %%
tr_col = ['StopName', 'WeekBeginning', 'type_x', 'latitude',
       'longitude', 'postcode', 'dist_from_centre', 'holiday_label']

# %%
x_train = train[tr_col]
x_test = test[tr_col]

# %%
y_train = train["NumberOfBoardings_sum"]
y_test = test["NumberOfBoardings_sum"]

# %%
y_train.shape
# Out:
# (155952,)

# %%
y_test.shape
# Out:
# (19494,)

# %%
x_train.shape
# Out:
# (155952, 8)

# %%
x_test.shape
# Out:
# (19494, 8)

# %%
x_train
# Out:
#                             StopName  WeekBeginning           type_x  \
# 0                        1 Anzac Hwy              0   street_address
# 1                        1 Anzac Hwy              1   street_address
# 2                        1 Anzac Hwy              2   street_address
# 3                        1 Anzac Hwy              3   street_address
# 4                        1 Anzac Hwy              4   street_address
# ...                              ...            ...              ...
# 175435  Zone I Salisbury Interchange             43  transit_station
# 175436  Zone I Salisbury Interchange             44  transit_station
# 175437  Zone I Salisbury Interchange             45  transit_station
# 175438  Zone I Salisbury Interchange             46  transit_station
# 175439  Zone I Salisbury Interchange             47  transit_station
#
#          latitude   longitude  postcode  dist_from_centre  holiday_label
# 0      -34.942418  138.581830      5035          3.151684              0
# 1      -34.942418  138.581830      5035          3.151684              0
# 2      -34.942418  138.581830      5035          3.151684              0
# 3      -34.942418  138.581830      5035          3.151684              0
# 4      -34.942418  138.581830      5035          3.151684              0
# ...           ...         ...       ...               ...            ...
# 175435 -34.763408  138.642747      5108         17.894924              0
# 175436 -34.763408  138.642747      5108         17.894924              0
# 175437 -34.763408  138.642747      5108         17.894924              0
# 175438 -34.763408  138.642747      5108         17.894924              0
# 175439 -34.763408  138.642747      5108         17.894924              0
#
# [155952 rows x 8 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
train['StopName'] = le.fit_transform(train['StopName'])
train['type_x'] = le.fit_transform(train['type_x'])

test['StopName'] = le.fit_transform(test['StopName'])
test['type_x'] = le.fit_transform(test['type_x'])
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9864\2957242744.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['StopName'] = le.fit_transform(train['StopName'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9864\2957242744.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['type_x'] = le.fit_transform(train['type_x'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9864\2957242744.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['StopName'] = le.fit_transform(test['StopName'])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9864\2957242744.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['type_x'] = le.fit_transform(test['type_x'])

# %%
train.head()
# Out:
#    StopName  WeekBeginning  type_x  NumberOfBoardings_sum  \
# 0         0              0       7                   1003
# 1         0              1       7                    783
# 2         0              2       7                    843
# 3         0              3       7                    710
# 4         0              4       7                    898
#
#    NumberOfBoardings_count  NumberOfBoardings_max   latitude  longitude  \
# 0                      378                     51 -34.942418  138.58183
# 1                      360                     28 -34.942418  138.58183
# 2                      343                     45 -34.942418  138.58183
# 3                      356                     28 -34.942418  138.58183
# 4                      379                     41 -34.942418  138.58183
#
#    postcode  dist_from_centre  holiday_label
# 0      5035          3.151684              0
# 1      5035          3.151684              0
# 2      5035          3.151684              0
# 3      5035          3.151684              0
# 4      5035          3.151684              0

# %%
test.head()
# Out:
#     StopName  WeekBeginning  type_x  NumberOfBoardings_sum  \
# 48         0              0       7                    613
# 49         0              1       7                    590
# 50         0              2       7                    700
# 51         0              3       7                    632
# 52         0              4       7                    876
#
#     NumberOfBoardings_count  NumberOfBoardings_max   latitude  longitude  \
# 48                      271                     59 -34.942418  138.58183
# 49                      282                     52 -34.942418  138.58183
# 50                      279                     60 -34.942418  138.58183
# 51                      321                     26 -34.942418  138.58183
# 52                      318                    158 -34.942418  138.58183
#
#     postcode  dist_from_centre  holiday_label
# 48      5035          3.151684              0
# 49      5035          3.151684              0
# 50      5035          3.151684              0
# 51      5035          3.151684              0
# 52      5035          3.151684              0

# %%
# bb1.head()

# %%
x_train= train[tr_col]
x_test = test[tr_col]

# %%
from sklearn.linear_model import LinearRegression  
regressor= LinearRegression()  
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(x_test)

# %%
y_pred
# Out:
# array([ 36.73340035,  36.51730157,  36.3012028 , ..., 730.73913649,
#        730.52303772, 730.30693894])

# %%
y_test = np.array(y_test)

# %%
np.concatenate((y_pred.reshape(-1,1), y_test.reshape(-1,1)),1)
# Out:
# array([[  36.73340035,  613.        ],
#        [  36.51730157,  590.        ],
#        [  36.3012028 ,  700.        ],
#        ...,
#        [ 730.73913649,  896.        ],
#        [ 730.52303772, 1052.        ],
#        [ 730.30693894,  534.        ]])

# %%
import sklearn.metrics
rms = sqrt(sklearn.metrics.mean_squared_error(y_test, y_pred))
rms
# Out:
# 739.750063796537

# %%
from sklearn.ensemble import RandomForestClassifier
# model = lgb.LGBMRegressor()
model = RandomForestClassifier(n_estimators=100)
# model = lgb.LGBMRegressor(max_depth=10,learning_rate=0.0227,n_estimators=195,num_leaves=11,reg_alpha=1.5764,reg_lambda=0.0478,subsample=0.7776,colsample_bytree=0.7761)
model.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9864\1951553473.py in <module>
#       3 model = RandomForestClassifier(n_estimators=100)
#       4 # model = lgb.LGBMRegressor(max_depth=10,learning_rate=0.0227,n_estimators=195,num_leaves=11,reg_alpha=1.5764,reg_lambda=0.0478,subsample=0.7776,colsample_bytree=0.7761)
# ----> 5 model.fit(x_train,y_train)
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in fit(self, X, y, sample_weight)
#     448             # parallel_backend contexts set at a higher level,
#     449             # since correctness does not rely on using threads.
# --> 450             trees = Parallel(
#     451                 n_jobs=self.n_jobs,
#     452                 verbose=self.verbose,
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1041             # remaining jobs.
#    1042             self._iterating = False
# -> 1043             if self.dispatch_one_batch(iterator):
#    1044                 self._iterating = self._original_iterator is not None
#    1045
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     859                 return False
#     860             else:
# --> 861                 self._dispatch(tasks)
#     862                 return True
#     863
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     777         with self._lock:
#     778             job_idx = len(self._jobs)
# --> 779             job = self._backend.apply_async(batch, callback=cb)
#     780             # A job can complete so quickly than its callback is
#     781             # called before we get here, causing self._jobs to
#
# ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~\anaconda3\lib\site-packages\sklearn\utils\fixes.py in __call__(self, *args, **kwargs)
#     214     def __call__(self, *args, **kwargs):
#     215         with config_context(**self.config):
# --> 216             return self.function(*args, **kwargs)
#     217
#     218
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in _parallel_build_trees(tree, forest, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap)
#     183             curr_sample_weight *= compute_sample_weight("balanced", y, indices=indices)
#     184
# --> 185         tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     186     else:
#     187         tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     935         """
#     936
# --> 937         super().fit(
#     938             X,
#     939             y,
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     418             )
#     419
# --> 420         builder.build(self.tree_, X, y, sample_weight)
#     421
#     422         if self.n_outputs_ == 1 and is_classifier(self):
#
# sklearn\tree\_tree.pyx in sklearn.tree._tree.DepthFirstTreeBuilder.build()
#
# sklearn\tree\_tree.pyx in sklearn.tree._tree.DepthFirstTreeBuilder.build()
#
# sklearn\tree\_tree.pyx in sklearn.tree._tree.Tree._add_node()
#
# sklearn\tree\_tree.pyx in sklearn.tree._tree.Tree._resize_c()
#
# sklearn\tree\_utils.pyx in sklearn.tree._utils.safe_realloc()
#
# MemoryError: could not allocate 9648996352 bytes

# %%
model.predict(x_test)

# %%
y_pred=np.array(y_test)

# %%
rms = sqrt(sklearn.metrics.mean_squared_error(y_test, y_pred))
rms

# %%
import sklearn.metrics
sklearn.metrics.mean_squared_error(np.array(y_pred),np.array(y_test))**0.5

# %% [markdown]
# # SVM

# %%
from sklearn.svm import SVC
classifier = SVC(kernel='linear', random_state=0) 
classifier.fit(x_train, y_train)

# %%
y_pred = classifier.predict(x_test)

# %%
y_pred

# %%
y_test

# %%
from sklearn.metrics import confusion_matrix  
cm= confusion_matrix(y_test, y_pred)  
cm

# %% [markdown]
#    # Polynomial regression

# %%
from sklearn.linear_model import LinearRegression  
lin_regs= LinearRegression()

# %% [markdown]
# # KNN Classification

# %%
from sklearn.neighbors import KNeighborsClassifier
model=KNeighborsClassifier(n_neighbors=5,metric='minkowski')
model1=model.fit(x_train,y_train)
model
